# %% [markdown]
# # Probabilistic program synthesis for tabular data using CrossCat+CGPM
#
# <img src="../resources/bayesian-program-synthesis.jpg"/>

# %% [markdown]
# $$
# \mathcal{G} =
#     \mathcal{G}^{\rm primitive} \; \lvert \;
#     \mathcal{G}\times\mathcal{G} \; \lvert \;
#     \mathcal{G} \stackrel{\rm chain}\to \mathcal{G} \; \lvert \;
#     [\mathcal{G}\dots\mathcal{G}] \; \lvert \;
#     \cup \mathcal{G}
# $$

# %%
import numpy as np
import pandas as pd

# %%
prng = np.random.RandomState(10)

# %% [markdown]
# #### Prepare the population schema.

# %%
schema = [
    ["Country_of_Operator",          ['categorical', {'k': 79}]],  # 0
    ["Operator_Owner",               ['categorical', {'k': 346}]], # 1
    ["Users",                        ['categorical', {'k': 18}]],  # 2
    ["Purpose",                      ['categorical', {'k': 46}]],  # 3
    ["Class_of_Orbit",               ['categorical', {'k': 4}]],   # 4
    ["Type_of_Orbit",                ['categorical', {'k': 7}]],   # 5
    ["Perigee_km",                   ['normal', None]],            # 6
    ["Apogee_km",                    ['normal', None]],            # 7
    ["Eccentricity",                 ['normal', None]],            # 8
    ["Period_minutes",               ['normal', None]],            # 9
    ["Launch_Mass_kg",               ['normal', None]],            # 10
    ["Dry_Mass_kg",                  ['normal', None]],            # 11
    ["Power_watts",                  ['normal', None]],            # 12
    ["Date_of_Launch",               ['normal', None]],            # 13
    ["Anticipated_Lifetime",         ['normal', None]],            # 14
    ["Contractor",                   ['categorical', {'k': 282}]], # 15
    ["Country_of_Contractor",        ['categorical', {'k': 54}]],  # 16
    ["Launch_Site",                  ['categorical', {'k': 25}]],  # 17
    ["Launch_Vehicle",               ['categorical', {'k': 141}]], # 18
    ["Source_Used_for_Orbital_Data", ['categorical', {'k': 38}]],  # 19
    ["longitude_radians_of_geo",     ['normal', None]],            # 20
    ["Inclination_radians",          ['normal', None]],            # 21
]

# %% [markdown]
# #### Sample an AST from the prior.

# %%
from cgpm2 import sample_crosscat

# %%
ast = sample_crosscat.generate_random_ast(schema, prng)

# %%
ast
# Out:
# [[[100000, ('crp', None), {'alpha': 1.121268}],
#   [[0, ['categorical', {'k': 79}], {'alpha': 0.719775}],
#    [8,
#     ['normal', None],
#     {'m': 1.710845, 'nu': 0.433329, 'r': 0.221829, 's': 1.943864}],
#    [11,
#     ['normal', None],
#     {'m': 0.163875, 'nu': 4.392115, 'r': 0.484694, 's': 2.88707}]]],
#  [[100001, ('crp', None), {'alpha': 0.583097}],
#   [[1, ['categorical', {'k': 346}], {'alpha': 1.050958}],
#    [4, ['categorical', {'k': 4}], {'alpha': 0.737407}],
#    [5, ['categorical', {'k': 7}], {'alpha': 2.393045}],
#    [7,
#     ['normal', None],
#     {'m': 1.76423, 'nu': 0.793158, 'r': 0.048032, 's': 0.984268}],
#    [12,
#     ['normal', None],
#     {'m': 0.609366, 'nu': 0.909741, 'r': 1.749406, 's': 0.289516}],
#    [16, ['categorical', {'k': 54}], {'alpha': 0.04078}],
#    [20,
#     ['normal', None],
#     {'m': 0.425179, 'nu': 1.440711, 'r': 0.044054, 's': 2.119557}],
#    [21,
#     ['normal', None],
#     {'m': 2.104527, 'nu': 0.72045, 'r': 0.540442, 's': 0.930333}]]],
#  [[100002, ('crp', None), {'alpha': 0.569186}],
#   [[2, ['categorical', {'k': 18}], {'alpha': 0.918891}],
#    [3, ['categorical', {'k': 46}], {'alpha': 1.635901}],
#    [6,
#     ['normal', None],
#     {'m': 0.38454, 'nu': 0.121021, 'r': 0.094816, 's': 0.357676}],
#    [9,
#     ['normal', None],
#     {'m': 1.40506, 'nu': 0.393801, 'r': 0.350923, 's': 2.153618}],
#    [13,
#     ['normal', None],
#     {'m': 2.331311, 'nu': 0.040074, 'r': 0.764768, 's': 0.892089}],
#    [14,
#     ['normal', None],
#     {'m': 0.441893, 'nu': 0.401552, 'r': 0.082961, 's': 0.364505}],
#    [15, ['categorical', {'k': 282}], {'alpha': 1.48647}],
#    [18, ['categorical', {'k': 141}], {'alpha': 0.37823}],
#    [19, ['categorical', {'k': 38}], {'alpha': 1.011952}]]],
#  [[100003, ('crp', None), {'alpha': 0.961725}],
#   [[10,
#     ['normal', None],
#     {'m': 0.180343, 'nu': 1.72096, 'r': 0.498451, 's': 0.098121}],
#    [17, ['categorical', {'k': 25}], {'alpha': 0.561228}]]]]

# %% [markdown]
# #### Compile the AST into the "Core DSL".

# %%
core_dsl = sample_crosscat.compile_ast_to_core_dsl(ast)

# %%
print core_dsl.getvalue()
# Out:
# - view:
#     row clustering model:
#       - crp{id:100000}:
#           distargs:
#           hypers:
#             alpha: 1.1213
#     distribution models:
#       - categorical{id:0}:
#           distargs:
#             k: 79
#           hypers:
#             alpha: 0.7198
#       - normal{id:8}:
#           distargs:
#           hypers:
#             s: 1.9439
#             r: 0.2218
#             m: 1.7108
#             nu: 0.4333
#       - normal{id:11}:
#           distargs:
#           hypers:
#             s: 2.8871
#             r: 0.4847
#             m: 0.1639
#             nu: 4.3921
# - view:
#     row clustering model:
#       - crp{id:100001}:
#           distargs:
#           hypers:
#             alpha: 0.5831
#     distribution models:
#       - categorical{id:1}:
#           distargs:
#             k: 346
#           hypers:
#             alpha: 1.0510
#       - categorical{id:4}:
#           distargs:
#             k: 4
#           hypers:
#             alpha: 0.7374
#       - categorical{id:5}:
#           distargs:
#             k: 7
#           hypers:
#             alpha: 2.3930
#       - normal{id:7}:
#           distargs:
#           hypers:
#             s: 0.9843
#             r: 0.0480
#             m: 1.7642
#             nu: 0.7932
#       - normal{id:12}:
#           distargs:
#           hypers:
#             s: 0.2895
#             r: 1.7494
#             m: 0.6094
#             nu: 0.9097
#       - categorical{id:16}:
#           distargs:
#             k: 54
#           hypers:
#             alpha: 0.0408
#       - normal{id:20}:
#           distargs:
#           hypers:
#             s: 2.1196
#             r: 0.0441
#             m: 0.4252
#             nu: 1.4407
#       - normal{id:21}:
#           distargs:
#           hypers:
#             s: 0.9303
#             r: 0.5404
#             m: 2.1045
#             nu: 0.7205
# - view:
#     row clustering model:
#       - crp{id:100002}:
#           distargs:
#           hypers:
#             alpha: 0.5692
#     distribution models:
#       - categorical{id:2}:
#           distargs:
#             k: 18
#           hypers:
#             alpha: 0.9189
#       - categorical{id:3}:
#           distargs:
#             k: 46
#           hypers:
#             alpha: 1.6359
#       - normal{id:6}:
#           distargs:
#           hypers:
#             s: 0.3577
#             r: 0.0948
#             m: 0.3845
#             nu: 0.1210
#       - normal{id:9}:
#           distargs:
#           hypers:
#             s: 2.1536
#             r: 0.3509
#             m: 1.4051
#             nu: 0.3938
#       - normal{id:13}:
#           distargs:
#           hypers:
#             s: 0.8921
#             r: 0.7648
#             m: 2.3313
#             nu: 0.0401
#       - normal{id:14}:
#           distargs:
#           hypers:
#             s: 0.3645
#             r: 0.0830
#             m: 0.4419
#             nu: 0.4016
#       - categorical{id:15}:
#           distargs:
#             k: 282
#           hypers:
#             alpha: 1.4865
#       - categorical{id:18}:
#           distargs:
#             k: 141
#           hypers:
#             alpha: 0.3782
#       - categorical{id:19}:
#           distargs:
#             k: 38
#           hypers:
#             alpha: 1.0120
# - view:
#     row clustering model:
#       - crp{id:100003}:
#           distargs:
#           hypers:
#             alpha: 0.9617
#     distribution models:
#       - normal{id:10}:
#           distargs:
#           hypers:
#             s: 0.0981
#             r: 0.4985
#             m: 0.1803
#             nu: 1.7210
#       - categorical{id:17}:
#           distargs:
#             k: 25
#           hypers:
#             alpha: 0.5612

# %% [markdown]
# #### Compile "Core DSL" into the "Embedded DSL".

# %%
embedded_dsl = sample_crosscat.compile_core_dsl_to_embedded_dsl(core_dsl.getvalue())

# %%
print embedded_dsl.getvalue()
# Out:
# from cgpm2.categorical import Categorical
# from cgpm2.crp import CRP
# from cgpm2.flexible_rowmix import FlexibleRowMixture
# from cgpm2.normal import Normal
# from cgpm2.poisson import Poisson
# from cgpm2.product import Product
#
# nan = float('nan')
#
# view0 = FlexibleRowMixture(
#   cgpm_row_divide=CRP(outputs=[100000], inputs=[], hypers={'alpha': 1.1213},),
#   cgpm_components_base=Product(cgpms=[
#     Categorical(outputs=[0], inputs=[], distargs={'k': 79}, hypers={'alpha': 0.7198},),
#     Normal(outputs=[8], inputs=[], hypers={'s': 1.9439, 'r': 0.2218, 'm': 1.7108, 'nu': 0.4333},),
#     Normal(outputs=[11], inputs=[], hypers={'s': 2.8871, 'r': 0.4847, 'm': 0.1639, 'nu': 4.3921},),])
# )
# view1 = FlexibleRowMixture(
#   cgpm_row_divide=CRP(outputs=[100001], inputs=[], hypers={'alpha': 0.5831},),
#   cgpm_components_base=Product(cgpms=[
#     Categorical(outputs=[1], inputs=[], distargs={'k': 346}, hypers={'alpha': 1.051},),
#     Categorical(outputs=[4], inputs=[], distargs={'k': 4}, hypers={'alpha': 0.7374},),
#     Categorical(outputs=[5], inputs=[], distargs={'k': 7}, hypers={'alpha': 2.393},),
#     Normal(outputs=[7], inputs=[], hypers={'s': 0.9843, 'r': 0.048, 'm': 1.7642, 'nu': 0.7932},),
#     Normal(outputs=[12], inputs=[], hypers={'s': 0.2895, 'r': 1.7494, 'm': 0.6094, 'nu': 0.9097},),
#     Categorical(outputs=[16], inputs=[], distargs={'k': 54}, hypers={'alpha': 0.0408},),
#     Normal(outputs=[20], inputs=[], hypers={'s': 2.1196, 'r': 0.0441, 'm': 0.4252, 'nu': 1.4407},),
#     Normal(outputs=[21], inputs=[], hypers={'s': 0.9303, 'r': 0.5404, 'm': 2.1045, 'nu': 0.7205},),])
# )
# view2 = FlexibleRowMixture(
#   cgpm_row_divide=CRP(outputs=[100002], inputs=[], hypers={'alpha': 0.5692},),
#   cgpm_components_base=Product(cgpms=[
#     Categorical(outputs=[2], inputs=[], distargs={'k': 18}, hypers={'alpha': 0.9189},),
#     Categorical(outputs=[3], inputs=[], distargs={'k': 46}, hypers={'alpha': 1.6359},),
#     Normal(outputs=[6], inputs=[], hypers={'s': 0.3577, 'r': 0.0948, 'm': 0.3845, 'nu': 0.121},),
#     Normal(outputs=[9], inputs=[], hypers={'s': 2.1536, 'r': 0.3509, 'm': 1.4051, 'nu': 0.3938},),
#     Normal(outputs=[13], inputs=[], hypers={'s': 0.8921, 'r': 0.7648, 'm': 2.3313, 'nu': 0.0401},),
#     Normal(outputs=[14], inputs=[], hypers={'s': 0.3645, 'r': 0.083, 'm': 0.4419, 'nu': 0.4016},),
#     Categorical(outputs=[15], inputs=[], distargs={'k': 282}, hypers={'alpha': 1.4865},),
#     Categorical(outputs=[18], inputs=[], distargs={'k': 141}, hypers={'alpha': 0.3782},),
#     Categorical(outputs=[19], inputs=[], distargs={'k': 38}, hypers={'alpha': 1.012},),])
# )
# view3 = FlexibleRowMixture(
#   cgpm_row_divide=CRP(outputs=[100003], inputs=[], hypers={'alpha': 0.9617},),
#   cgpm_components_base=Product(cgpms=[
#     Normal(outputs=[10], inputs=[], hypers={'s': 0.0981, 'r': 0.4985, 'm': 0.1803, 'nu': 1.721},),
#     Categorical(outputs=[17], inputs=[], distargs={'k': 25}, hypers={'alpha': 0.5612},),])
# )
# crosscat = Product(cgpms=[view0, view1, view2, view3])

# %% [markdown]
# #### Execute the Embeddd DSL source code to build the model trace.

# %%
exec(embedded_dsl.getvalue())

# %%
crosscat

# %% [markdown]
# #### Load observations for .csv file and observe them into the model trace.

# %%
df = pd.read_csv('../resources/satellites.coded.csv', index_col=False)
for rowid, values in df.iterrows():
    observation = dict(zip(range(len(values)), values.values))
    crosscat.observe(rowid, observation)

# %% [raw]
# crosscat.render()

# %% [markdown]
# #### Run Bayesian synthesis.

# %%
from cgpm2.transition_crosscat import GibbsCrossCat
synthesizer = GibbsCrossCat(crosscat)
synthesizer.transition_structure_cpp(N=10)
synthesizer.transition(N=10, kernels=['hypers_distributions', 'hypers_row_divide'])
# Out:
# Completed: 10 iterations in 2.671450 seconds.
# Completed: 10 iterations in 28.322833 seconds.

# %% [markdown]
# #### Render the posterior model trace as Embedded DSL + sequence of observes that reconstruct it exactly.

# %%
print sample_crosscat.render_trace_in_embedded_dsl(synthesizer.crosscat).getvalue()
# Out:
# from cgpm2.categorical import Categorical
# from cgpm2.crp import CRP
# from cgpm2.flexible_rowmix import FlexibleRowMixture
# from cgpm2.normal import Normal
# from cgpm2.poisson import Poisson
# from cgpm2.product import Product
#
# nan = float('nan')
#
# view0 = FlexibleRowMixture(
#   cgpm_row_divide=CRP(outputs=[385995556], inputs=[], hypers={'alpha': 2.0763},),
#   cgpm_components_base=Product(cgpms=[
#     Normal(outputs=[8], inputs=[], hypers={'s': 0.1953, 'r': 0.0009, 'm': 0.4119, 'nu': 1166.0},),])
# )
# view1 = FlexibleRowMixture(
#   cgpm_row_divide=CRP(outputs=[1677575585], inputs=[], hypers={'alpha': 3.3791},),
#   cgpm_components_base=Product(cgpms=[
#     Categorical(outputs=[1], inputs=[], distargs={'k': 346}, hypers={'alpha': 0.2959},),
#     Categorical(outputs=[4], inputs=[], distargs={'k': 4}, hypers={'alpha': 0.0159},),
#     Normal(outputs=[7], inputs=[], hypers={'s': 9456749226.0409, 'r': 0.0009, 'm': 97557.9655, 'nu': 1166.0},),
#     Normal(outputs=[21], inputs=[], hypers={'s': 12.0679, 'r': 0.0023, 'm': 1.0367, 'nu': 270.158},),
#     Categorical(outputs=[2], inputs=[], distargs={'k': 18}, hypers={'alpha': 0.1117},),
#     Categorical(outputs=[3], inputs=[], distargs={'k': 46}, hypers={'alpha': 0.1117},),
#     Normal(outputs=[6], inputs=[], hypers={'s': 3225808161.1001, 'r': 0.0098, 'm': 11855.2759, 'nu': 1166.0},),
#     Normal(outputs=[9], inputs=[], hypers={'s': 8858425.3593, 'r': 0.0009, 'm': 2038.6921, 'nu': 1165.0},),
#     Normal(outputs=[14], inputs=[], hypers={'s': 220.1809, 'r': 0.7916, 'm': 8.4483, 'nu': 20.8688},),
#     Categorical(outputs=[18], inputs=[], distargs={'k': 141}, hypers={'alpha': 0.1819},),
#     Categorical(outputs=[19], inputs=[], distargs={'k': 38}, hypers={'alpha': 0.0693},),
#     Categorical(outputs=[17], inputs=[], distargs={'k': 25}, hypers={'alpha': 0.1117},),])
# )
# view2 = FlexibleRowMixture(
#   cgpm_row_divide=CRP(outputs=[2222803971], inputs=[], hypers={'alpha': 2.0763},),
#   cgpm_components_base=Product(cgpms=[
#     Categorical(outputs=[0], inputs=[], distargs={'k': 79}, hypers={'alpha': 0.1818},),
#     Categorical(outputs=[5], inputs=[], distargs={'k': 7}, hypers={'alpha': 0.0932},),
#     Categorical(outputs=[16], inputs=[], distargs={'k': 54}, hypers={'alpha': 0.1818},),
#     Normal(outputs=[20], inputs=[], hypers={'s': 52.084, 'r': 0.2313, 'm': 1.6758, 'nu': 28.4122},),
#     Normal(outputs=[13], inputs=[], hypers={'s': 56622528.6643, 'r': 0.7839, 'm': 37716.931, 'nu': 18.5771},),
#     Categorical(outputs=[15], inputs=[], distargs={'k': 282}, hypers={'alpha': 0.2962},),])
# )
# view3 = FlexibleRowMixture(
#   cgpm_row_divide=CRP(outputs=[2646888559], inputs=[], hypers={'alpha': 1.2757},),
#   cgpm_components_base=Product(cgpms=[
#     Normal(outputs=[11], inputs=[], hypers={'s': 9711432.8657, 'r': 0.0265, 'm': 3795.6207, 'nu': 88.7305},),
#     Normal(outputs=[12], inputs=[], hypers={'s': 129552890.0562, 'r': 0.2122, 'm': 2071.2759, 'nu': 67.1729},),
#     Normal(outputs=[10], inputs=[], hypers={'s': 57332857.4868, 'r': 0.0064, 'm': 5588.3103, 'nu': 199.946},),])
# )
# crosscat = Product(cgpms=[view0, view1, view2, view3])
#
# # Incorporates for view 0.
# crosscat.observe(0, {8: 0.00119, 385995556: 0})
# crosscat.observe(1, {8: 0.0002, 385995556: 0})
# crosscat.observe(2, {8: 5e-05, 385995556: 0})
# crosscat.observe(3, {8: 0.00015, 385995556: 0})
# crosscat.observe(4, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(5, {8: 0.00283, 385995556: 0})
# crosscat.observe(6, {8: 0.005370000000000001, 385995556: 0})
# crosscat.observe(7, {8: 0.00468, 385995556: 0})
# crosscat.observe(8, {8: 0.00264, 385995556: 0})
# crosscat.observe(9, {8: 0.0, 385995556: 0})
# crosscat.observe(10, {8: 0.0004, 385995556: 0})
# crosscat.observe(11, {8: 0.00273, 385995556: 0})
# crosscat.observe(12, {8: 0.0, 385995556: 0})
# crosscat.observe(13, {8: 0.0, 385995556: 0})
# crosscat.observe(14, {8: 0.02213, 385995556: 0})
# crosscat.observe(15, {8: 0.0211, 385995556: 0})
# crosscat.observe(17, {8: 0.03149, 385995556: 0})
# crosscat.observe(18, {8: 0.03149, 385995556: 0})
# crosscat.observe(19, {8: 0.0005200000000000001, 385995556: 0})
# crosscat.observe(20, {8: 4e-05, 385995556: 0})
# crosscat.observe(21, {8: 0.00038, 385995556: 0})
# crosscat.observe(22, {8: 0.00039, 385995556: 0})
# crosscat.observe(23, {8: 0.0017399999999999998, 385995556: 0})
# crosscat.observe(24, {8: 0.00094, 385995556: 0})
# crosscat.observe(25, {8: 0.00122, 385995556: 0})
# crosscat.observe(26, {8: 0.00193, 385995556: 0})
# crosscat.observe(27, {8: 0.00173, 385995556: 0})
# crosscat.observe(29, {8: 0.03149, 385995556: 0})
# crosscat.observe(30, {8: 1e-05, 385995556: 0})
# crosscat.observe(31, {8: 0.00014, 385995556: 0})
# crosscat.observe(32, {8: 0.00025, 385995556: 0})
# crosscat.observe(33, {8: 0.00045, 385995556: 0})
# crosscat.observe(34, {8: 0.00012, 385995556: 0})
# crosscat.observe(35, {8: 0.00033, 385995556: 0})
# crosscat.observe(36, {8: 0.00026000000000000003, 385995556: 0})
# crosscat.observe(37, {8: 0.00027, 385995556: 0})
# crosscat.observe(38, {8: 0.00021, 385995556: 0})
# crosscat.observe(39, {8: 0.00015, 385995556: 0})
# crosscat.observe(40, {8: 0.00032, 385995556: 0})
# crosscat.observe(41, {8: 0.00028, 385995556: 0})
# crosscat.observe(42, {8: 0.00018, 385995556: 0})
# crosscat.observe(43, {8: 0.00021, 385995556: 0})
# crosscat.observe(44, {8: 0.00012, 385995556: 0})
# crosscat.observe(45, {8: 0.00023, 385995556: 0})
# crosscat.observe(46, {8: 0.0002, 385995556: 0})
# crosscat.observe(47, {8: 0.0003, 385995556: 0})
# crosscat.observe(48, {8: 0.0003, 385995556: 0})
# crosscat.observe(49, {8: 0.0003, 385995556: 0})
# crosscat.observe(50, {8: 0.00019, 385995556: 0})
# crosscat.observe(51, {8: 7e-05, 385995556: 0})
# crosscat.observe(52, {8: 0.00194, 385995556: 0})
# crosscat.observe(53, {8: 0.00488, 385995556: 0})
# crosscat.observe(54, {8: 0.00121, 385995556: 0})
# crosscat.observe(55, {8: 0.00018, 385995556: 0})
# crosscat.observe(56, {8: 0.00021, 385995556: 0})
# crosscat.observe(57, {8: 0.00011, 385995556: 0})
# crosscat.observe(58, {8: 0.00019, 385995556: 0})
# crosscat.observe(59, {8: 0.00031, 385995556: 0})
# crosscat.observe(60, {8: 0.00479, 385995556: 0})
# crosscat.observe(61, {8: 0.01092, 385995556: 0})
# crosscat.observe(62, {8: 0.00065, 385995556: 0})
# crosscat.observe(63, {8: 0.00499, 385995556: 0})
# crosscat.observe(64, {8: 0.00598, 385995556: 0})
# crosscat.observe(65, {8: 0.00476, 385995556: 0})
# crosscat.observe(66, {8: 0.004220000000000001, 385995556: 0})
# crosscat.observe(67, {8: 0.00536, 385995556: 0})
# crosscat.observe(68, {8: 0.00015, 385995556: 0})
# crosscat.observe(69, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(70, {8: 0.00019, 385995556: 0})
# crosscat.observe(71, {8: 0.00012, 385995556: 0})
# crosscat.observe(72, {8: 0.00046, 385995556: 0})
# crosscat.observe(73, {8: 0.00019, 385995556: 0})
# crosscat.observe(74, {8: 0.00019, 385995556: 0})
# crosscat.observe(75, {8: 0.00038, 385995556: 0})
# crosscat.observe(76, {8: 0.00014, 385995556: 0})
# crosscat.observe(77, {8: 6e-05, 385995556: 0})
# crosscat.observe(78, {8: 0.0002, 385995556: 0})
# crosscat.observe(79, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(80, {8: 0.00033, 385995556: 0})
# crosscat.observe(81, {8: 0.00023, 385995556: 0})
# crosscat.observe(82, {8: 0.0003, 385995556: 0})
# crosscat.observe(83, {8: 0.00023, 385995556: 0})
# crosscat.observe(84, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(85, {8: 0.00021, 385995556: 0})
# crosscat.observe(86, {8: 0.00049, 385995556: 0})
# crosscat.observe(87, {8: 0.00031, 385995556: 0})
# crosscat.observe(88, {8: 0.00057, 385995556: 0})
# crosscat.observe(89, {8: 0.0007700000000000001, 385995556: 0})
# crosscat.observe(90, {8: 0.00025, 385995556: 0})
# crosscat.observe(91, {8: 0.00034, 385995556: 0})
# crosscat.observe(92, {8: 0.00043, 385995556: 0})
# crosscat.observe(93, {8: 0.00038, 385995556: 0})
# crosscat.observe(94, {8: 0.00014, 385995556: 0})
# crosscat.observe(95, {8: 0.00021, 385995556: 0})
# crosscat.observe(96, {8: 0.0004, 385995556: 0})
# crosscat.observe(97, {8: 0.00045, 385995556: 0})
# crosscat.observe(98, {8: 0.00019, 385995556: 0})
# crosscat.observe(99, {8: 0.00204, 385995556: 0})
# crosscat.observe(100, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(101, {8: 0.00058, 385995556: 0})
# crosscat.observe(102, {8: 0.00021, 385995556: 0})
# crosscat.observe(103, {8: 0.00044, 385995556: 0})
# crosscat.observe(105, {8: 0.00173, 385995556: 0})
# crosscat.observe(106, {8: 0.00195, 385995556: 0})
# crosscat.observe(107, {8: 0.00156, 385995556: 0})
# crosscat.observe(108, {8: 0.00153, 385995556: 0})
# crosscat.observe(109, {8: 0.00029, 385995556: 0})
# crosscat.observe(110, {8: 0.00021, 385995556: 0})
# crosscat.observe(111, {8: 0.00025, 385995556: 0})
# crosscat.observe(112, {8: 0.0004, 385995556: 0})
# crosscat.observe(113, {8: 0.00033, 385995556: 0})
# crosscat.observe(114, {8: 0.02053, 385995556: 0})
# crosscat.observe(115, {8: 0.00019, 385995556: 0})
# crosscat.observe(116, {8: 0.03261, 385995556: 0})
# crosscat.observe(117, {8: 4e-05, 385995556: 0})
# crosscat.observe(118, {8: 0.02938, 385995556: 0})
# crosscat.observe(119, {8: 7e-05, 385995556: 0})
# crosscat.observe(120, {8: 0.00029, 385995556: 0})
# crosscat.observe(121, {8: 0.00143, 385995556: 0})
# crosscat.observe(122, {8: 0.00084, 385995556: 0})
# crosscat.observe(123, {8: 0.00143, 385995556: 0})
# crosscat.observe(124, {8: 0.00044, 385995556: 0})
# crosscat.observe(125, {8: 7e-05, 385995556: 0})
# crosscat.observe(126, {8: 0.00021, 385995556: 0})
# crosscat.observe(127, {8: 0.00136, 385995556: 0})
# crosscat.observe(128, {8: 0.00164, 385995556: 0})
# crosscat.observe(130, {8: 0.00043, 385995556: 0})
# crosscat.observe(132, {8: 0.00024, 385995556: 0})
# crosscat.observe(133, {8: 0.00134, 385995556: 0})
# crosscat.observe(134, {8: 0.00133, 385995556: 0})
# crosscat.observe(135, {8: 0.0014, 385995556: 0})
# crosscat.observe(136, {8: 0.00338, 385995556: 0})
# crosscat.observe(137, {8: 7e-05, 385995556: 0})
# crosscat.observe(138, {8: 0.02191, 385995556: 0})
# crosscat.observe(139, {8: 0.00974, 385995556: 0})
# crosscat.observe(140, {8: 0.01087, 385995556: 0})
# crosscat.observe(141, {8: 7e-05, 385995556: 0})
# crosscat.observe(142, {8: 0.00042, 385995556: 0})
# crosscat.observe(143, {8: 0.00185, 385995556: 0})
# crosscat.observe(144, {8: 0.00027, 385995556: 0})
# crosscat.observe(145, {8: 0.00027, 385995556: 0})
# crosscat.observe(146, {8: 0.00053, 385995556: 0})
# crosscat.observe(147, {8: 0.00265, 385995556: 0})
# crosscat.observe(148, {8: 0.00028, 385995556: 0})
# crosscat.observe(149, {8: 0.00119, 385995556: 0})
# crosscat.observe(150, {8: 0.02525, 385995556: 0})
# crosscat.observe(151, {8: 0.00203, 385995556: 0})
# crosscat.observe(152, {8: 0.00047, 385995556: 0})
# crosscat.observe(153, {8: 0.00242, 385995556: 0})
# crosscat.observe(154, {8: 0.00271, 385995556: 0})
# crosscat.observe(155, {8: 0.00231, 385995556: 0})
# crosscat.observe(156, {8: 0.0017399999999999998, 385995556: 0})
# crosscat.observe(157, {8: 9e-05, 385995556: 0})
# crosscat.observe(158, {8: 0.00031, 385995556: 0})
# crosscat.observe(159, {8: 0.00017, 385995556: 0})
# crosscat.observe(160, {8: 0.00146, 385995556: 0})
# crosscat.observe(161, {8: 0.00502, 385995556: 0})
# crosscat.observe(162, {8: 0.00432, 385995556: 0})
# crosscat.observe(163, {8: 0.00544, 385995556: 0})
# crosscat.observe(164, {8: 0.00683, 385995556: 0})
# crosscat.observe(165, {8: 0.00391, 385995556: 0})
# crosscat.observe(166, {8: 7e-05, 385995556: 0})
# crosscat.observe(167, {8: 7e-05, 385995556: 0})
# crosscat.observe(168, {8: 7e-05, 385995556: 0})
# crosscat.observe(170, {8: 0.00078, 385995556: 0})
# crosscat.observe(171, {8: 0.00164, 385995556: 0})
# crosscat.observe(172, {8: 0.00861, 385995556: 0})
# crosscat.observe(173, {8: 0.00104, 385995556: 0})
# crosscat.observe(174, {8: 0.00177, 385995556: 0})
# crosscat.observe(175, {8: 0.03149, 385995556: 0})
# crosscat.observe(177, {8: 0.00104, 385995556: 0})
# crosscat.observe(178, {8: 0.00136, 385995556: 0})
# crosscat.observe(180, {8: 7e-05, 385995556: 0})
# crosscat.observe(181, {8: 0.00129, 385995556: 0})
# crosscat.observe(182, {8: 0.01318, 385995556: 0})
# crosscat.observe(183, {8: 4e-05, 385995556: 0})
# crosscat.observe(184, {8: 0.0, 385995556: 0})
# crosscat.observe(185, {8: 1e-05, 385995556: 0})
# crosscat.observe(186, {8: 0.0002, 385995556: 0})
# crosscat.observe(187, {8: 0.00014, 385995556: 0})
# crosscat.observe(188, {8: 0.00031, 385995556: 0})
# crosscat.observe(189, {8: 0.00027, 385995556: 0})
# crosscat.observe(190, {8: 0.00023, 385995556: 0})
# crosscat.observe(191, {8: 0.00028, 385995556: 0})
# crosscat.observe(192, {8: 0.00141, 385995556: 0})
# crosscat.observe(193, {8: 0.0006900000000000001, 385995556: 0})
# crosscat.observe(194, {8: 0.0009, 385995556: 0})
# crosscat.observe(195, {8: 0.00097, 385995556: 0})
# crosscat.observe(196, {8: 0.00062, 385995556: 0})
# crosscat.observe(197, {8: 0.0009, 385995556: 0})
# crosscat.observe(198, {8: 0.00118, 385995556: 0})
# crosscat.observe(199, {8: 0.0016600000000000002, 385995556: 0})
# crosscat.observe(200, {8: 0.015619999999999997, 385995556: 0})
# crosscat.observe(201, {8: 0.015619999999999997, 385995556: 0})
# crosscat.observe(202, {8: 0.00028, 385995556: 0})
# crosscat.observe(203, {8: 0.00037, 385995556: 0})
# crosscat.observe(204, {8: 0.00064, 385995556: 0})
# crosscat.observe(205, {8: 0.0007099999999999999, 385995556: 0})
# crosscat.observe(206, {8: 0.00192, 385995556: 0})
# crosscat.observe(207, {8: 0.0003, 385995556: 0})
# crosscat.observe(208, {8: 0.00162, 385995556: 0})
# crosscat.observe(209, {8: 0.00072, 385995556: 0})
# crosscat.observe(210, {8: 0.0, 385995556: 0})
# crosscat.observe(211, {8: 0.00024, 385995556: 0})
# crosscat.observe(212, {8: 0.00014, 385995556: 0})
# crosscat.observe(213, {8: 0.00053, 385995556: 0})
# crosscat.observe(214, {8: 0.00108, 385995556: 0})
# crosscat.observe(215, {8: 0.00128, 385995556: 0})
# crosscat.observe(216, {8: 0.00129, 385995556: 0})
# crosscat.observe(217, {8: 0.0030800000000000003, 385995556: 0})
# crosscat.observe(218, {8: 0.00023, 385995556: 0})
# crosscat.observe(220, {8: 0.00018, 385995556: 0})
# crosscat.observe(221, {8: 0.00011, 385995556: 0})
# crosscat.observe(222, {8: 5e-05, 385995556: 0})
# crosscat.observe(223, {8: 0.00017, 385995556: 0})
# crosscat.observe(224, {8: 0.00024, 385995556: 0})
# crosscat.observe(225, {8: 0.00015, 385995556: 0})
# crosscat.observe(226, {8: 8e-05, 385995556: 0})
# crosscat.observe(227, {8: 0.00027, 385995556: 0})
# crosscat.observe(229, {8: 7e-05, 385995556: 0})
# crosscat.observe(230, {8: 0.00026000000000000003, 385995556: 0})
# crosscat.observe(231, {8: 0.00031, 385995556: 0})
# crosscat.observe(232, {8: 0.00391, 385995556: 0})
# crosscat.observe(233, {8: 0.00509, 385995556: 0})
# crosscat.observe(235, {8: 0.00106, 385995556: 0})
# crosscat.observe(236, {8: 0.00121, 385995556: 0})
# crosscat.observe(237, {8: 0.00106, 385995556: 0})
# crosscat.observe(238, {8: 0.00085, 385995556: 0})
# crosscat.observe(239, {8: 7e-05, 385995556: 0})
# crosscat.observe(240, {8: 7e-05, 385995556: 0})
# crosscat.observe(241, {8: 0.00021, 385995556: 0})
# crosscat.observe(242, {8: 0.00123, 385995556: 0})
# crosscat.observe(243, {8: 0.00044, 385995556: 0})
# crosscat.observe(245, {8: 0.00092, 385995556: 0})
# crosscat.observe(246, {8: 0.00058, 385995556: 0})
# crosscat.observe(247, {8: 0.00024, 385995556: 0})
# crosscat.observe(248, {8: 0.00049, 385995556: 0})
# crosscat.observe(249, {8: 0.00044, 385995556: 0})
# crosscat.observe(250, {8: 0.00019, 385995556: 0})
# crosscat.observe(251, {8: 0.00057, 385995556: 0})
# crosscat.observe(252, {8: 0.00075, 385995556: 0})
# crosscat.observe(253, {8: 0.00032, 385995556: 0})
# crosscat.observe(254, {8: 0.00038, 385995556: 0})
# crosscat.observe(255, {8: 0.0005, 385995556: 0})
# crosscat.observe(256, {8: 0.00012, 385995556: 0})
# crosscat.observe(257, {8: 7e-05, 385995556: 0})
# crosscat.observe(258, {8: 0.00011, 385995556: 0})
# crosscat.observe(259, {8: 0.00047, 385995556: 0})
# crosscat.observe(260, {8: 1e-05, 385995556: 0})
# crosscat.observe(261, {8: 0.00018, 385995556: 0})
# crosscat.observe(262, {8: 0.00047, 385995556: 0})
# crosscat.observe(263, {8: 0.00012, 385995556: 0})
# crosscat.observe(264, {8: 0.0006900000000000001, 385995556: 0})
# crosscat.observe(265, {8: 0.00024, 385995556: 0})
# crosscat.observe(266, {8: 0.00043, 385995556: 0})
# crosscat.observe(267, {8: 0.0003, 385995556: 0})
# crosscat.observe(268, {8: 0.00024, 385995556: 0})
# crosscat.observe(269, {8: 0.00039, 385995556: 0})
# crosscat.observe(270, {8: 0.00047, 385995556: 0})
# crosscat.observe(271, {8: 0.00028, 385995556: 0})
# crosscat.observe(272, {8: 0.0007, 385995556: 0})
# crosscat.observe(273, {8: 0.00063, 385995556: 0})
# crosscat.observe(274, {8: 1e-05, 385995556: 0})
# crosscat.observe(275, {8: 0.00168, 385995556: 0})
# crosscat.observe(276, {8: 0.00104, 385995556: 0})
# crosscat.observe(277, {8: 0.00011, 385995556: 0})
# crosscat.observe(278, {8: 8e-05, 385995556: 0})
# crosscat.observe(279, {8: 0.00028, 385995556: 0})
# crosscat.observe(280, {8: 4e-05, 385995556: 0})
# crosscat.observe(281, {8: 0.00021, 385995556: 0})
# crosscat.observe(282, {8: 0.00011, 385995556: 0})
# crosscat.observe(283, {8: 9e-05, 385995556: 0})
# crosscat.observe(284, {8: 0.00618, 385995556: 0})
# crosscat.observe(285, {8: 0.00014, 385995556: 0})
# crosscat.observe(286, {8: 0.00193, 385995556: 0})
# crosscat.observe(287, {8: 0.0008699999999999999, 385995556: 0})
# crosscat.observe(288, {8: 0.0008699999999999999, 385995556: 0})
# crosscat.observe(289, {8: 0.00017, 385995556: 0})
# crosscat.observe(290, {8: 0.00043, 385995556: 0})
# crosscat.observe(291, {8: 0.00066, 385995556: 0})
# crosscat.observe(292, {8: 0.00104, 385995556: 0})
# crosscat.observe(293, {8: 7e-05, 385995556: 0})
# crosscat.observe(294, {8: 7e-05, 385995556: 0})
# crosscat.observe(295, {8: 0.00137, 385995556: 0})
# crosscat.observe(296, {8: 0.0004, 385995556: 0})
# crosscat.observe(297, {8: 0.0026100000000000003, 385995556: 0})
# crosscat.observe(298, {8: 0.00101, 385995556: 0})
# crosscat.observe(299, {8: 0.03149, 385995556: 0})
# crosscat.observe(300, {8: 0.03149, 385995556: 0})
# crosscat.observe(301, {8: 0.00044, 385995556: 0})
# crosscat.observe(302, {8: 0.001, 385995556: 0})
# crosscat.observe(303, {8: 0.00021, 385995556: 0})
# crosscat.observe(304, {8: 0.0023, 385995556: 0})
# crosscat.observe(305, {8: 0.00635, 385995556: 0})
# crosscat.observe(306, {8: 0.00012, 385995556: 0})
# crosscat.observe(307, {8: 0.00025, 385995556: 0})
# crosscat.observe(308, {8: 0.00011, 385995556: 0})
# crosscat.observe(309, {8: 0.00023, 385995556: 0})
# crosscat.observe(310, {8: 0.00023, 385995556: 0})
# crosscat.observe(311, {8: 0.00027, 385995556: 0})
# crosscat.observe(312, {8: 0.0003, 385995556: 0})
# crosscat.observe(313, {8: 0.00028, 385995556: 0})
# crosscat.observe(314, {8: 0.00024, 385995556: 0})
# crosscat.observe(315, {8: 0.00036, 385995556: 0})
# crosscat.observe(316, {8: 0.0002, 385995556: 0})
# crosscat.observe(317, {8: 0.00021, 385995556: 0})
# crosscat.observe(318, {8: 0.00027, 385995556: 0})
# crosscat.observe(319, {8: 5e-05, 385995556: 0})
# crosscat.observe(320, {8: 0.0011, 385995556: 0})
# crosscat.observe(321, {8: 0.00111, 385995556: 0})
# crosscat.observe(322, {8: 0.00032, 385995556: 0})
# crosscat.observe(323, {8: 0.00017, 385995556: 0})
# crosscat.observe(324, {8: 0.00171, 385995556: 0})
# crosscat.observe(325, {8: 9e-05, 385995556: 0})
# crosscat.observe(326, {8: 0.00032, 385995556: 0})
# crosscat.observe(327, {8: 0.015969999999999998, 385995556: 0})
# crosscat.observe(328, {8: 0.0034, 385995556: 0})
# crosscat.observe(329, {8: 0.00564, 385995556: 0})
# crosscat.observe(330, {8: 0.00106, 385995556: 0})
# crosscat.observe(332, {8: 0.00021, 385995556: 0})
# crosscat.observe(333, {8: 0.00032, 385995556: 0})
# crosscat.observe(334, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(335, {8: 0.00103, 385995556: 0})
# crosscat.observe(336, {8: 0.00019, 385995556: 0})
# crosscat.observe(337, {8: 0.00019, 385995556: 0})
# crosscat.observe(338, {8: 0.00026000000000000003, 385995556: 0})
# crosscat.observe(339, {8: 0.03408, 385995556: 0})
# crosscat.observe(340, {8: 6e-05, 385995556: 0})
# crosscat.observe(341, {8: 0.00039, 385995556: 0})
# crosscat.observe(343, {8: 6e-05, 385995556: 0})
# crosscat.observe(344, {8: 0.00019, 385995556: 0})
# crosscat.observe(345, {8: 6e-05, 385995556: 0})
# crosscat.observe(346, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(347, {8: 6e-05, 385995556: 0})
# crosscat.observe(348, {8: 0.00032, 385995556: 0})
# crosscat.observe(349, {8: 0.00019, 385995556: 0})
# crosscat.observe(350, {8: 6e-05, 385995556: 0})
# crosscat.observe(351, {8: 0.00019, 385995556: 0})
# crosscat.observe(352, {8: 0.00032, 385995556: 0})
# crosscat.observe(353, {8: 0.00019, 385995556: 0})
# crosscat.observe(354, {8: 0.00019, 385995556: 0})
# crosscat.observe(355, {8: 0.00026000000000000003, 385995556: 0})
# crosscat.observe(356, {8: 6e-05, 385995556: 0})
# crosscat.observe(357, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(358, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(359, {8: 0.00019, 385995556: 0})
# crosscat.observe(360, {8: 6e-05, 385995556: 0})
# crosscat.observe(361, {8: 0.00019, 385995556: 0})
# crosscat.observe(362, {8: 6e-05, 385995556: 0})
# crosscat.observe(363, {8: 6e-05, 385995556: 0})
# crosscat.observe(364, {8: 0.00019, 385995556: 0})
# crosscat.observe(365, {8: 6e-05, 385995556: 0})
# crosscat.observe(366, {8: 6e-05, 385995556: 0})
# crosscat.observe(367, {8: 6e-05, 385995556: 0})
# crosscat.observe(368, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(369, {8: 6e-05, 385995556: 0})
# crosscat.observe(370, {8: 0.00019, 385995556: 0})
# crosscat.observe(371, {8: 0.01757, 385995556: 0})
# crosscat.observe(372, {8: 6e-05, 385995556: 0})
# crosscat.observe(373, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(374, {8: 6e-05, 385995556: 0})
# crosscat.observe(375, {8: 0.0025800000000000003, 385995556: 0})
# crosscat.observe(376, {8: 0.00082, 385995556: 0})
# crosscat.observe(377, {8: 0.00058, 385995556: 0})
# crosscat.observe(378, {8: 0.0006900000000000001, 385995556: 0})
# crosscat.observe(379, {8: 0.00135, 385995556: 0})
# crosscat.observe(380, {8: 0.00059, 385995556: 0})
# crosscat.observe(381, {8: 0.00014, 385995556: 0})
# crosscat.observe(382, {8: 0.00014, 385995556: 0})
# crosscat.observe(383, {8: 0.0, 385995556: 0})
# crosscat.observe(384, {8: 0.0, 385995556: 0})
# crosscat.observe(385, {8: 0.0, 385995556: 0})
# crosscat.observe(386, {8: 0.00151, 385995556: 0})
# crosscat.observe(387, {8: 0.00018, 385995556: 0})
# crosscat.observe(388, {8: 0.0046, 385995556: 0})
# crosscat.observe(390, {8: 0.00425, 385995556: 0})
# crosscat.observe(391, {8: 0.00096, 385995556: 0})
# crosscat.observe(392, {8: 0.00022, 385995556: 0})
# crosscat.observe(393, {8: 0.0001, 385995556: 0})
# crosscat.observe(394, {8: 0.00059, 385995556: 0})
# crosscat.observe(395, {8: 0.00419, 385995556: 0})
# crosscat.observe(396, {8: 0.0056, 385995556: 0})
# crosscat.observe(397, {8: 0.00053, 385995556: 0})
# crosscat.observe(398, {8: 4e-05, 385995556: 0})
# crosscat.observe(399, {8: 0.00524, 385995556: 0})
# crosscat.observe(400, {8: 0.00061, 385995556: 0})
# crosscat.observe(401, {8: 0.00014, 385995556: 0})
# crosscat.observe(402, {8: 0.00421, 385995556: 0})
# crosscat.observe(404, {8: 0.00188, 385995556: 0})
# crosscat.observe(405, {8: 0.00063, 385995556: 0})
# crosscat.observe(406, {8: 0.00121, 385995556: 0})
# crosscat.observe(407, {8: 0.00096, 385995556: 0})
# crosscat.observe(408, {8: 0.00143, 385995556: 0})
# crosscat.observe(409, {8: 0.00063, 385995556: 0})
# crosscat.observe(410, {8: 0.00169, 385995556: 0})
# crosscat.observe(411, {8: 0.00039, 385995556: 0})
# crosscat.observe(412, {8: 0.0, 385995556: 0})
# crosscat.observe(413, {8: 2e-05, 385995556: 0})
# crosscat.observe(414, {8: 0.00033, 385995556: 0})
# crosscat.observe(415, {8: 0.00149, 385995556: 0})
# crosscat.observe(416, {8: 0.00109, 385995556: 0})
# crosscat.observe(417, {8: 0.00064, 385995556: 0})
# crosscat.observe(418, {8: 0.00058, 385995556: 0})
# crosscat.observe(419, {8: 0.0008300000000000001, 385995556: 0})
# crosscat.observe(420, {8: 0.00203, 385995556: 0})
# crosscat.observe(421, {8: 0.00159, 385995556: 0})
# crosscat.observe(422, {8: 0.00197, 385995556: 0})
# crosscat.observe(423, {8: 0.00095, 385995556: 0})
# crosscat.observe(424, {8: 0.00095, 385995556: 0})
# crosscat.observe(425, {8: 0.0011, 385995556: 0})
# crosscat.observe(426, {8: 0.00125, 385995556: 0})
# crosscat.observe(427, {8: 0.00014, 385995556: 0})
# crosscat.observe(428, {8: 0.00021, 385995556: 0})
# crosscat.observe(429, {8: 0.00059, 385995556: 0})
# crosscat.observe(430, {8: 0.00056, 385995556: 0})
# crosscat.observe(431, {8: 0.00024, 385995556: 0})
# crosscat.observe(432, {8: 0.0006799999999999999, 385995556: 0})
# crosscat.observe(433, {8: 0.00017, 385995556: 0})
# crosscat.observe(434, {8: 0.00147, 385995556: 0})
# crosscat.observe(435, {8: 0.00014, 385995556: 0})
# crosscat.observe(436, {8: 0.0025, 385995556: 0})
# crosscat.observe(437, {8: 0.00014, 385995556: 0})
# crosscat.observe(438, {8: 0.00021, 385995556: 0})
# crosscat.observe(439, {8: 0.0004, 385995556: 0})
# crosscat.observe(440, {8: 0.00116, 385995556: 0})
# crosscat.observe(441, {8: 0.00184, 385995556: 0})
# crosscat.observe(442, {8: 0.013669999999999998, 385995556: 0})
# crosscat.observe(443, {8: 0.0005200000000000001, 385995556: 0})
# crosscat.observe(444, {8: 0.00053, 385995556: 0})
# crosscat.observe(445, {8: 5e-05, 385995556: 0})
# crosscat.observe(446, {8: 0.00264, 385995556: 0})
# crosscat.observe(447, {8: 0.00371, 385995556: 0})
# crosscat.observe(448, {8: 0.00102, 385995556: 0})
# crosscat.observe(449, {8: 0.00036, 385995556: 0})
# crosscat.observe(450, {8: 0.00023, 385995556: 0})
# crosscat.observe(451, {8: 0.00135, 385995556: 0})
# crosscat.observe(452, {8: 0.00029, 385995556: 0})
# crosscat.observe(453, {8: 0.00358, 385995556: 0})
# crosscat.observe(454, {8: 0.00039, 385995556: 0})
# crosscat.observe(455, {8: 0.00028, 385995556: 0})
# crosscat.observe(456, {8: 0.00351, 385995556: 0})
# crosscat.observe(457, {8: 0.00044, 385995556: 0})
# crosscat.observe(458, {8: 0.00058, 385995556: 0})
# crosscat.observe(459, {8: 0.00058, 385995556: 0})
# crosscat.observe(460, {8: 0.00022, 385995556: 0})
# crosscat.observe(461, {8: 0.00015, 385995556: 0})
# crosscat.observe(462, {8: 0.00036, 385995556: 0})
# crosscat.observe(463, {8: nan, 385995556: 0})
# crosscat.observe(464, {8: 0.00014, 385995556: 0})
# crosscat.observe(467, {8: 0.00121, 385995556: 0})
# crosscat.observe(468, {8: 0.0005200000000000001, 385995556: 0})
# crosscat.observe(469, {8: 0.00055, 385995556: 0})
# crosscat.observe(470, {8: 0.00039, 385995556: 0})
# crosscat.observe(471, {8: 0.0004, 385995556: 0})
# crosscat.observe(472, {8: 0.00032, 385995556: 0})
# crosscat.observe(473, {8: 0.00032, 385995556: 0})
# crosscat.observe(474, {8: 0.00027, 385995556: 0})
# crosscat.observe(475, {8: 7e-05, 385995556: 0})
# crosscat.observe(476, {8: 0.00015, 385995556: 0})
# crosscat.observe(477, {8: 0.00053, 385995556: 0})
# crosscat.observe(478, {8: 0.00011, 385995556: 0})
# crosscat.observe(479, {8: 0.0005, 385995556: 0})
# crosscat.observe(480, {8: 0.00023, 385995556: 0})
# crosscat.observe(481, {8: 0.0006, 385995556: 0})
# crosscat.observe(482, {8: 0.0001, 385995556: 0})
# crosscat.observe(484, {8: 0.00024, 385995556: 0})
# crosscat.observe(485, {8: 7e-05, 385995556: 0})
# crosscat.observe(486, {8: 0.0002, 385995556: 0})
# crosscat.observe(487, {8: 0.00034, 385995556: 0})
# crosscat.observe(488, {8: 0.00026000000000000003, 385995556: 0})
# crosscat.observe(489, {8: 9e-05, 385995556: 0})
# crosscat.observe(490, {8: 0.0004, 385995556: 0})
# crosscat.observe(491, {8: 0.00026000000000000003, 385995556: 0})
# crosscat.observe(492, {8: 0.00039, 385995556: 0})
# crosscat.observe(493, {8: 4e-05, 385995556: 0})
# crosscat.observe(494, {8: 0.00012, 385995556: 0})
# crosscat.observe(495, {8: 0.00044, 385995556: 0})
# crosscat.observe(496, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(497, {8: 0.00019, 385995556: 0})
# crosscat.observe(498, {8: 0.00018, 385995556: 0})
# crosscat.observe(499, {8: 0.00018, 385995556: 0})
# crosscat.observe(500, {8: 0.00028, 385995556: 0})
# crosscat.observe(501, {8: 0.0002, 385995556: 0})
# crosscat.observe(502, {8: 0.00026000000000000003, 385995556: 0})
# crosscat.observe(503, {8: 0.00026000000000000003, 385995556: 0})
# crosscat.observe(504, {8: 0.00024, 385995556: 0})
# crosscat.observe(505, {8: 0.00023, 385995556: 0})
# crosscat.observe(506, {8: 0.00028, 385995556: 0})
# crosscat.observe(507, {8: 0.00026000000000000003, 385995556: 0})
# crosscat.observe(508, {8: 0.00012, 385995556: 0})
# crosscat.observe(509, {8: 0.00027, 385995556: 0})
# crosscat.observe(510, {8: 0.00026000000000000003, 385995556: 0})
# crosscat.observe(512, {8: 8e-05, 385995556: 0})
# crosscat.observe(513, {8: 0.00044, 385995556: 0})
# crosscat.observe(514, {8: 0.00025, 385995556: 0})
# crosscat.observe(515, {8: 0.00039, 385995556: 0})
# crosscat.observe(516, {8: 0.00042, 385995556: 0})
# crosscat.observe(517, {8: 0.00109, 385995556: 0})
# crosscat.observe(518, {8: 0.00155, 385995556: 0})
# crosscat.observe(520, {8: 0.02986, 385995556: 0})
# crosscat.observe(521, {8: 0.00021, 385995556: 0})
# crosscat.observe(522, {8: 0.00021, 385995556: 0})
# crosscat.observe(523, {8: 0.00021, 385995556: 0})
# crosscat.observe(524, {8: 0.00028, 385995556: 0})
# crosscat.observe(525, {8: 0.00021, 385995556: 0})
# crosscat.observe(526, {8: 0.00021, 385995556: 0})
# crosscat.observe(527, {8: 0.00021, 385995556: 0})
# crosscat.observe(528, {8: 0.00021, 385995556: 0})
# crosscat.observe(529, {8: 0.00021, 385995556: 0})
# crosscat.observe(530, {8: 0.00035, 385995556: 0})
# crosscat.observe(531, {8: 0.00021, 385995556: 0})
# crosscat.observe(532, {8: 0.00021, 385995556: 0})
# crosscat.observe(533, {8: 0.00021, 385995556: 0})
# crosscat.observe(534, {8: 0.00021, 385995556: 0})
# crosscat.observe(535, {8: 0.00028, 385995556: 0})
# crosscat.observe(536, {8: 0.00021, 385995556: 0})
# crosscat.observe(537, {8: 0.00021, 385995556: 0})
# crosscat.observe(538, {8: 0.00021, 385995556: 0})
# crosscat.observe(539, {8: 0.00021, 385995556: 0})
# crosscat.observe(540, {8: 0.00021, 385995556: 0})
# crosscat.observe(541, {8: 0.00021, 385995556: 0})
# crosscat.observe(542, {8: 0.00021, 385995556: 0})
# crosscat.observe(543, {8: 0.00021, 385995556: 0})
# crosscat.observe(544, {8: 0.00021, 385995556: 0})
# crosscat.observe(545, {8: 0.00021, 385995556: 0})
# crosscat.observe(546, {8: 0.00021, 385995556: 0})
# crosscat.observe(547, {8: 0.00021, 385995556: 0})
# crosscat.observe(548, {8: 0.00028, 385995556: 0})
# crosscat.observe(549, {8: 0.00021, 385995556: 0})
# crosscat.observe(550, {8: 0.00021, 385995556: 0})
# crosscat.observe(551, {8: 0.00028, 385995556: 0})
# crosscat.observe(552, {8: 0.00021, 385995556: 0})
# crosscat.observe(553, {8: 0.00021, 385995556: 0})
# crosscat.observe(554, {8: 0.00021, 385995556: 0})
# crosscat.observe(555, {8: 0.00021, 385995556: 0})
# crosscat.observe(556, {8: 0.00021, 385995556: 0})
# crosscat.observe(557, {8: 0.00021, 385995556: 0})
# crosscat.observe(558, {8: 0.00021, 385995556: 0})
# crosscat.observe(559, {8: 0.00021, 385995556: 0})
# crosscat.observe(560, {8: 0.00028, 385995556: 0})
# crosscat.observe(561, {8: 0.00028, 385995556: 0})
# crosscat.observe(562, {8: 0.00021, 385995556: 0})
# crosscat.observe(563, {8: 0.00021, 385995556: 0})
# crosscat.observe(564, {8: 0.00021, 385995556: 0})
# crosscat.observe(565, {8: 0.00021, 385995556: 0})
# crosscat.observe(566, {8: 0.00021, 385995556: 0})
# crosscat.observe(567, {8: 0.00021, 385995556: 0})
# crosscat.observe(568, {8: 0.00021, 385995556: 0})
# crosscat.observe(569, {8: 0.00021, 385995556: 0})
# crosscat.observe(570, {8: 0.00021, 385995556: 0})
# crosscat.observe(571, {8: 0.00021, 385995556: 0})
# crosscat.observe(572, {8: 0.00021, 385995556: 0})
# crosscat.observe(573, {8: 0.00021, 385995556: 0})
# crosscat.observe(574, {8: 0.00028, 385995556: 0})
# crosscat.observe(575, {8: 0.00021, 385995556: 0})
# crosscat.observe(576, {8: 0.00028, 385995556: 0})
# crosscat.observe(577, {8: 0.00028, 385995556: 0})
# crosscat.observe(578, {8: 0.00021, 385995556: 0})
# crosscat.observe(579, {8: 0.00021, 385995556: 0})
# crosscat.observe(580, {8: 0.00021, 385995556: 0})
# crosscat.observe(581, {8: 0.00021, 385995556: 0})
# crosscat.observe(582, {8: 0.00021, 385995556: 0})
# crosscat.observe(583, {8: 0.00021, 385995556: 0})
# crosscat.observe(584, {8: 0.00028, 385995556: 0})
# crosscat.observe(585, {8: 0.00063, 385995556: 0})
# crosscat.observe(586, {8: 7e-05, 385995556: 0})
# crosscat.observe(587, {8: 0.00063, 385995556: 0})
# crosscat.observe(588, {8: 0.00021, 385995556: 0})
# crosscat.observe(589, {8: 0.00063, 385995556: 0})
# crosscat.observe(590, {8: 7e-05, 385995556: 0})
# crosscat.observe(591, {8: 0.00014, 385995556: 0})
# crosscat.observe(592, {8: 0.00314, 385995556: 0})
# crosscat.observe(593, {8: 0.0019, 385995556: 0})
# crosscat.observe(594, {8: 0.00042, 385995556: 0})
# crosscat.observe(595, {8: 0.00078, 385995556: 0})
# crosscat.observe(596, {8: 0.00078, 385995556: 0})
# crosscat.observe(597, {8: 0.00034, 385995556: 0})
# crosscat.observe(598, {8: 6e-05, 385995556: 0})
# crosscat.observe(599, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(600, {8: 0.00019, 385995556: 0})
# crosscat.observe(601, {8: 7e-05, 385995556: 0})
# crosscat.observe(603, {8: 0.00025, 385995556: 0})
# crosscat.observe(604, {8: 0.00017, 385995556: 0})
# crosscat.observe(605, {8: 0.00187, 385995556: 0})
# crosscat.observe(606, {8: 7e-05, 385995556: 0})
# crosscat.observe(607, {8: 2e-05, 385995556: 0})
# crosscat.observe(608, {8: 0.0, 385995556: 0})
# crosscat.observe(613, {8: 0.00017, 385995556: 0})
# crosscat.observe(614, {8: 0.00024, 385995556: 0})
# crosscat.observe(615, {8: 0.00114, 385995556: 0})
# crosscat.observe(616, {8: 0.00156, 385995556: 0})
# crosscat.observe(617, {8: 0.0012, 385995556: 0})
# crosscat.observe(618, {8: 0.00123, 385995556: 0})
# crosscat.observe(619, {8: 0.00029, 385995556: 0})
# crosscat.observe(620, {8: 0.00014, 385995556: 0})
# crosscat.observe(621, {8: 0.00017, 385995556: 0})
# crosscat.observe(622, {8: 0.00195, 385995556: 0})
# crosscat.observe(623, {8: 7e-05, 385995556: 0})
# crosscat.observe(624, {8: 0.00028, 385995556: 0})
# crosscat.observe(625, {8: 0.00729, 385995556: 0})
# crosscat.observe(626, {8: 0.00021, 385995556: 0})
# crosscat.observe(627, {8: 7e-05, 385995556: 0})
# crosscat.observe(629, {8: 0.00143, 385995556: 0})
# crosscat.observe(630, {8: 0.00414, 385995556: 0})
# crosscat.observe(631, {8: 0.00811, 385995556: 0})
# crosscat.observe(632, {8: 0.00062, 385995556: 0})
# crosscat.observe(633, {8: 0.0007599999999999999, 385995556: 0})
# crosscat.observe(634, {8: 0.00018, 385995556: 0})
# crosscat.observe(635, {8: 0.00034, 385995556: 0})
# crosscat.observe(636, {8: 0.00204, 385995556: 0})
# crosscat.observe(638, {8: 0.02562, 385995556: 0})
# crosscat.observe(639, {8: 0.03149, 385995556: 0})
# crosscat.observe(640, {8: 0.00011, 385995556: 0})
# crosscat.observe(641, {8: 0.00019, 385995556: 0})
# crosscat.observe(642, {8: 0.0007099999999999999, 385995556: 0})
# crosscat.observe(643, {8: 0.00104, 385995556: 0})
# crosscat.observe(644, {8: 0.00448, 385995556: 0})
# crosscat.observe(649, {8: 0.00014, 385995556: 0})
# crosscat.observe(650, {8: 8e-05, 385995556: 0})
# crosscat.observe(651, {8: 0.00032, 385995556: 0})
# crosscat.observe(652, {8: 0.00014, 385995556: 0})
# crosscat.observe(653, {8: 0.00024, 385995556: 0})
# crosscat.observe(654, {8: 7e-05, 385995556: 0})
# crosscat.observe(655, {8: 0.00021, 385995556: 0})
# crosscat.observe(656, {8: 8e-05, 385995556: 0})
# crosscat.observe(657, {8: 0.0007700000000000001, 385995556: 0})
# crosscat.observe(658, {8: 0.0005200000000000001, 385995556: 0})
# crosscat.observe(659, {8: 5e-05, 385995556: 0})
# crosscat.observe(660, {8: 0.00079, 385995556: 0})
# crosscat.observe(661, {8: 0.00045, 385995556: 0})
# crosscat.observe(662, {8: 0.00184, 385995556: 0})
# crosscat.observe(663, {8: 0.00111, 385995556: 0})
# crosscat.observe(664, {8: 0.00104, 385995556: 0})
# crosscat.observe(665, {8: 0.00149, 385995556: 0})
# crosscat.observe(666, {8: 0.00055, 385995556: 0})
# crosscat.observe(667, {8: 0.00024, 385995556: 0})
# crosscat.observe(668, {8: 0.00182, 385995556: 0})
# crosscat.observe(669, {8: 0.00021, 385995556: 0})
# crosscat.observe(670, {8: 0.00025, 385995556: 0})
# crosscat.observe(671, {8: 0.0, 385995556: 0})
# crosscat.observe(672, {8: 0.00118, 385995556: 0})
# crosscat.observe(673, {8: 0.00036, 385995556: 0})
# crosscat.observe(674, {8: 0.00636, 385995556: 0})
# crosscat.observe(675, {8: 0.00024, 385995556: 0})
# crosscat.observe(676, {8: 0.01508, 385995556: 0})
# crosscat.observe(677, {8: 0.00836, 385995556: 0})
# crosscat.observe(678, {8: 0.00234, 385995556: 0})
# crosscat.observe(679, {8: 0.00294, 385995556: 0})
# crosscat.observe(680, {8: 0.0062, 385995556: 0})
# crosscat.observe(681, {8: 0.00384, 385995556: 0})
# crosscat.observe(682, {8: 0.00175, 385995556: 0})
# crosscat.observe(683, {8: 0.01011, 385995556: 0})
# crosscat.observe(684, {8: 0.00279, 385995556: 0})
# crosscat.observe(685, {8: 0.0006799999999999999, 385995556: 0})
# crosscat.observe(686, {8: 0.00024, 385995556: 0})
# crosscat.observe(687, {8: 0.00032, 385995556: 0})
# crosscat.observe(688, {8: 0.00118, 385995556: 0})
# crosscat.observe(689, {8: 0.00686, 385995556: 0})
# crosscat.observe(690, {8: 0.00352, 385995556: 0})
# crosscat.observe(691, {8: 0.00414, 385995556: 0})
# crosscat.observe(692, {8: 0.00919, 385995556: 0})
# crosscat.observe(693, {8: 0.00233, 385995556: 0})
# crosscat.observe(694, {8: 0.00324, 385995556: 0})
# crosscat.observe(695, {8: 0.0019, 385995556: 0})
# crosscat.observe(696, {8: 0.00455, 385995556: 0})
# crosscat.observe(697, {8: 0.00601, 385995556: 0})
# crosscat.observe(698, {8: 0.00305, 385995556: 0})
# crosscat.observe(699, {8: 0.00355, 385995556: 0})
# crosscat.observe(700, {8: 0.00695, 385995556: 0})
# crosscat.observe(701, {8: 0.00149, 385995556: 0})
# crosscat.observe(702, {8: 0.00606, 385995556: 0})
# crosscat.observe(703, {8: 0.003, 385995556: 0})
# crosscat.observe(704, {8: 0.00121, 385995556: 0})
# crosscat.observe(705, {8: 0.00303, 385995556: 0})
# crosscat.observe(706, {8: 0.00032, 385995556: 0})
# crosscat.observe(707, {8: 0.00092, 385995556: 0})
# crosscat.observe(708, {8: 0.00098, 385995556: 0})
# crosscat.observe(709, {8: 0.0005200000000000001, 385995556: 0})
# crosscat.observe(710, {8: 2e-05, 385995556: 0})
# crosscat.observe(711, {8: 0.00099, 385995556: 0})
# crosscat.observe(712, {8: 0.00248, 385995556: 0})
# crosscat.observe(713, {8: 0.0005200000000000001, 385995556: 0})
# crosscat.observe(714, {8: 0.00021, 385995556: 0})
# crosscat.observe(715, {8: 0.00017, 385995556: 0})
# crosscat.observe(717, {8: 0.0, 385995556: 0})
# crosscat.observe(719, {8: 0.00111, 385995556: 0})
# crosscat.observe(720, {8: 0.00104, 385995556: 0})
# crosscat.observe(721, {8: 0.00145, 385995556: 0})
# crosscat.observe(722, {8: 0.00131, 385995556: 0})
# crosscat.observe(723, {8: 0.0, 385995556: 0})
# crosscat.observe(724, {8: 0.00022, 385995556: 0})
# crosscat.observe(725, {8: 0.0002, 385995556: 0})
# crosscat.observe(726, {8: 0.00026000000000000003, 385995556: 0})
# crosscat.observe(727, {8: 0.00017, 385995556: 0})
# crosscat.observe(728, {8: 0.00024, 385995556: 0})
# crosscat.observe(729, {8: 0.00025, 385995556: 0})
# crosscat.observe(730, {8: 0.00027, 385995556: 0})
# crosscat.observe(731, {8: 0.0003, 385995556: 0})
# crosscat.observe(732, {8: 0.00018, 385995556: 0})
# crosscat.observe(733, {8: 9e-05, 385995556: 0})
# crosscat.observe(734, {8: 0.00032, 385995556: 0})
# crosscat.observe(735, {8: 0.00136, 385995556: 0})
# crosscat.observe(736, {8: 0.00214, 385995556: 0})
# crosscat.observe(737, {8: 0.00021, 385995556: 0})
# crosscat.observe(738, {8: 0.00024, 385995556: 0})
# crosscat.observe(739, {8: 0.00014, 385995556: 0})
# crosscat.observe(740, {8: 0.00021, 385995556: 0})
# crosscat.observe(741, {8: 0.00014, 385995556: 0})
# crosscat.observe(742, {8: 0.00029, 385995556: 0})
# crosscat.observe(743, {8: 0.02862, 385995556: 0})
# crosscat.observe(744, {8: 0.01728, 385995556: 0})
# crosscat.observe(745, {8: 0.01799, 385995556: 0})
# crosscat.observe(746, {8: 0.01437, 385995556: 0})
# crosscat.observe(747, {8: 0.00031, 385995556: 0})
# crosscat.observe(748, {8: 0.00021, 385995556: 0})
# crosscat.observe(749, {8: 0.00027, 385995556: 0})
# crosscat.observe(750, {8: 0.0003, 385995556: 0})
# crosscat.observe(751, {8: 0.00024, 385995556: 0})
# crosscat.observe(752, {8: 0.00042, 385995556: 0})
# crosscat.observe(753, {8: 0.00056, 385995556: 0})
# crosscat.observe(754, {8: 0.00042, 385995556: 0})
# crosscat.observe(755, {8: 0.00049, 385995556: 0})
# crosscat.observe(756, {8: 0.00035, 385995556: 0})
# crosscat.observe(757, {8: 0.00049, 385995556: 0})
# crosscat.observe(758, {8: 0.00035, 385995556: 0})
# crosscat.observe(759, {8: 0.00063, 385995556: 0})
# crosscat.observe(760, {8: 0.00049, 385995556: 0})
# crosscat.observe(761, {8: 7e-05, 385995556: 0})
# crosscat.observe(762, {8: 0.00028, 385995556: 0})
# crosscat.observe(763, {8: 0.00042, 385995556: 0})
# crosscat.observe(764, {8: 0.00042, 385995556: 0})
# crosscat.observe(765, {8: 0.00014, 385995556: 0})
# crosscat.observe(766, {8: 0.00056, 385995556: 0})
# crosscat.observe(767, {8: 0.00049, 385995556: 0})
# crosscat.observe(768, {8: 0.0007, 385995556: 0})
# crosscat.observe(769, {8: 0.00063, 385995556: 0})
# crosscat.observe(770, {8: 0.00049, 385995556: 0})
# crosscat.observe(771, {8: 0.00049, 385995556: 0})
# crosscat.observe(772, {8: 0.00488, 385995556: 0})
# crosscat.observe(773, {8: 0.00014, 385995556: 0})
# crosscat.observe(774, {8: 0.00014, 385995556: 0})
# crosscat.observe(775, {8: 0.00021, 385995556: 0})
# crosscat.observe(776, {8: 0.0007, 385995556: 0})
# crosscat.observe(777, {8: 0.00056, 385995556: 0})
# crosscat.observe(778, {8: 0.00036, 385995556: 0})
# crosscat.observe(779, {8: 0.00036, 385995556: 0})
# crosscat.observe(780, {8: 0.00103, 385995556: 0})
# crosscat.observe(781, {8: 0.00036, 385995556: 0})
# crosscat.observe(782, {8: 0.01435, 385995556: 0})
# crosscat.observe(783, {8: 0.00017, 385995556: 0})
# crosscat.observe(784, {8: 6e-05, 385995556: 0})
# crosscat.observe(785, {8: 0.00014, 385995556: 0})
# crosscat.observe(786, {8: 1e-05, 385995556: 0})
# crosscat.observe(787, {8: 0.00014, 385995556: 0})
# crosscat.observe(788, {8: 0.00456, 385995556: 0})
# crosscat.observe(789, {8: 0.00319, 385995556: 0})
# crosscat.observe(790, {8: 0.00313, 385995556: 0})
# crosscat.observe(791, {8: 0.0032600000000000003, 385995556: 0})
# crosscat.observe(792, {8: 0.0034, 385995556: 0})
# crosscat.observe(793, {8: 0.0040100000000000005, 385995556: 0})
# crosscat.observe(794, {8: 0.00417, 385995556: 0})
# crosscat.observe(795, {8: 0.00388, 385995556: 0})
# crosscat.observe(796, {8: 0.00199, 385995556: 0})
# crosscat.observe(797, {8: 0.00367, 385995556: 0})
# crosscat.observe(798, {8: 0.00049, 385995556: 0})
# crosscat.observe(799, {8: 0.00134, 385995556: 0})
# crosscat.observe(800, {8: 0.00058, 385995556: 0})
# crosscat.observe(801, {8: 0.00028, 385995556: 0})
# crosscat.observe(802, {8: 0.00029, 385995556: 0})
# crosscat.observe(803, {8: 0.00014, 385995556: 0})
# crosscat.observe(804, {8: 0.00092, 385995556: 0})
# crosscat.observe(805, {8: 0.00193, 385995556: 0})
# crosscat.observe(806, {8: 0.00881, 385995556: 0})
# crosscat.observe(807, {8: 0.00141, 385995556: 0})
# crosscat.observe(808, {8: 0.00049, 385995556: 0})
# crosscat.observe(809, {8: 0.00044, 385995556: 0})
# crosscat.observe(810, {8: 0.00029, 385995556: 0})
# crosscat.observe(811, {8: 0.00029, 385995556: 0})
# crosscat.observe(812, {8: 0.00029, 385995556: 0})
# crosscat.observe(813, {8: 0.00029, 385995556: 0})
# crosscat.observe(814, {8: 0.00029, 385995556: 0})
# crosscat.observe(815, {8: 0.00029, 385995556: 0})
# crosscat.observe(816, {8: 0.00029, 385995556: 0})
# crosscat.observe(817, {8: 0.00365, 385995556: 0})
# crosscat.observe(818, {8: 0.00028, 385995556: 0})
# crosscat.observe(819, {8: 0.00015, 385995556: 0})
# crosscat.observe(821, {8: 0.00014, 385995556: 0})
# crosscat.observe(822, {8: 0.01668, 385995556: 0})
# crosscat.observe(823, {8: 0.004, 385995556: 0})
# crosscat.observe(824, {8: 5e-05, 385995556: 0})
# crosscat.observe(825, {8: 0.00024, 385995556: 0})
# crosscat.observe(826, {8: 0.0002, 385995556: 0})
# crosscat.observe(827, {8: 0.00236, 385995556: 0})
# crosscat.observe(828, {8: 0.00121, 385995556: 0})
# crosscat.observe(829, {8: 0.00114, 385995556: 0})
# crosscat.observe(830, {8: 0.00121, 385995556: 0})
# crosscat.observe(831, {8: 0.00179, 385995556: 0})
# crosscat.observe(832, {8: 0.00213, 385995556: 0})
# crosscat.observe(833, {8: 1e-05, 385995556: 0})
# crosscat.observe(834, {8: 0.00177, 385995556: 0})
# crosscat.observe(835, {8: 0.0030800000000000003, 385995556: 0})
# crosscat.observe(836, {8: 0.00042, 385995556: 0})
# crosscat.observe(837, {8: 0.0005, 385995556: 0})
# crosscat.observe(838, {8: 0.00095, 385995556: 0})
# crosscat.observe(839, {8: 0.00022, 385995556: 0})
# crosscat.observe(840, {8: 0.00088, 385995556: 0})
# crosscat.observe(841, {8: 0.0007700000000000001, 385995556: 0})
# crosscat.observe(842, {8: 0.00197, 385995556: 0})
# crosscat.observe(843, {8: 0.00203, 385995556: 0})
# crosscat.observe(844, {8: 0.00203, 385995556: 0})
# crosscat.observe(846, {8: 0.00159, 385995556: 0})
# crosscat.observe(847, {8: 0.0007, 385995556: 0})
# crosscat.observe(848, {8: 0.00019, 385995556: 0})
# crosscat.observe(849, {8: 0.00134, 385995556: 0})
# crosscat.observe(850, {8: 0.00197, 385995556: 0})
# crosscat.observe(851, {8: 0.00273, 385995556: 0})
# crosscat.observe(852, {8: 0.00273, 385995556: 0})
# crosscat.observe(853, {8: 0.00248, 385995556: 0})
# crosscat.observe(854, {8: 0.00197, 385995556: 0})
# crosscat.observe(855, {8: 0.00191, 385995556: 0})
# crosscat.observe(856, {8: 0.00184, 385995556: 0})
# crosscat.observe(858, {8: 0.00014, 385995556: 0})
# crosscat.observe(859, {8: 0.00014, 385995556: 0})
# crosscat.observe(862, {8: 0.00105, 385995556: 0})
# crosscat.observe(863, {8: 0.00021, 385995556: 0})
# crosscat.observe(864, {8: 0.0027, 385995556: 0})
# crosscat.observe(865, {8: 0.00241, 385995556: 0})
# crosscat.observe(866, {8: 0.00168, 385995556: 0})
# crosscat.observe(867, {8: 0.00278, 385995556: 0})
# crosscat.observe(868, {8: 0.00204, 385995556: 0})
# crosscat.observe(869, {8: 0.0002, 385995556: 0})
# crosscat.observe(870, {8: 0.00015, 385995556: 0})
# crosscat.observe(871, {8: 0.00024, 385995556: 0})
# crosscat.observe(872, {8: 0.00019, 385995556: 0})
# crosscat.observe(873, {8: 0.00353, 385995556: 0})
# crosscat.observe(874, {8: 0.00591, 385995556: 0})
# crosscat.observe(875, {8: 0.0044, 385995556: 0})
# crosscat.observe(876, {8: 0.00686, 385995556: 0})
# crosscat.observe(877, {8: 0.00524, 385995556: 0})
# crosscat.observe(878, {8: 0.00778, 385995556: 0})
# crosscat.observe(879, {8: 0.00609, 385995556: 0})
# crosscat.observe(880, {8: 0.00705, 385995556: 0})
# crosscat.observe(881, {8: 0.00268, 385995556: 0})
# crosscat.observe(882, {8: 0.00149, 385995556: 0})
# crosscat.observe(883, {8: 0.0002, 385995556: 0})
# crosscat.observe(884, {8: 0.00024, 385995556: 0})
# crosscat.observe(885, {8: 0.00022, 385995556: 0})
# crosscat.observe(886, {8: 0.0, 385995556: 0})
# crosscat.observe(887, {8: 0.0, 385995556: 0})
# crosscat.observe(888, {8: 0.01251, 385995556: 0})
# crosscat.observe(889, {8: 0.01277, 385995556: 0})
# crosscat.observe(890, {8: 0.0125, 385995556: 0})
# crosscat.observe(891, {8: 0.01243, 385995556: 0})
# crosscat.observe(892, {8: 0.01237, 385995556: 0})
# crosscat.observe(893, {8: 0.01237, 385995556: 0})
# crosscat.observe(894, {8: 0.0125, 385995556: 0})
# crosscat.observe(895, {8: 0.01243, 385995556: 0})
# crosscat.observe(896, {8: 0.01277, 385995556: 0})
# crosscat.observe(897, {8: 0.01277, 385995556: 0})
# crosscat.observe(898, {8: 0.004220000000000001, 385995556: 0})
# crosscat.observe(899, {8: 0.00176, 385995556: 0})
# crosscat.observe(900, {8: 0.00078, 385995556: 0})
# crosscat.observe(901, {8: 0.00014, 385995556: 0})
# crosscat.observe(902, {8: 0.0006799999999999999, 385995556: 0})
# crosscat.observe(903, {8: 0.0006, 385995556: 0})
# crosscat.observe(906, {8: 0.00039, 385995556: 0})
# crosscat.observe(907, {8: 0.0004, 385995556: 0})
# crosscat.observe(908, {8: 0.00085, 385995556: 0})
# crosscat.observe(909, {8: 0.00143, 385995556: 0})
# crosscat.observe(910, {8: 0.00014, 385995556: 0})
# crosscat.observe(911, {8: 0.00024, 385995556: 0})
# crosscat.observe(912, {8: 2e-05, 385995556: 0})
# crosscat.observe(913, {8: 0.00013000000000000002, 385995556: 0})
# crosscat.observe(914, {8: 9e-05, 385995556: 0})
# crosscat.observe(915, {8: 0.0007, 385995556: 0})
# crosscat.observe(916, {8: 8e-05, 385995556: 0})
# crosscat.observe(917, {8: 0.00021, 385995556: 0})
# crosscat.observe(918, {8: 0.0012, 385995556: 0})
# crosscat.observe(920, {8: 0.00106, 385995556: 0})
# crosscat.observe(921, {8: 0.00106, 385995556: 0})
# crosscat.observe(922, {8: 0.00129, 385995556: 0})
# crosscat.observe(923, {8: 0.00085, 385995556: 0})
# crosscat.observe(924, {8: 0.00122, 385995556: 0})
# crosscat.observe(925, {8: 0.00194, 385995556: 0})
# crosscat.observe(926, {8: 0.00079, 385995556: 0})
# crosscat.observe(927, {8: 0.00022, 385995556: 0})
# crosscat.observe(928, {8: 7e-05, 385995556: 0})
# crosscat.observe(929, {8: 0.00187, 385995556: 0})
# ...
# crosscat.observe(712, {10: 100.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(724, {10: 1.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(735, {10: 360.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(736, {10: 5.5, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(737, {10: 700.0, 11: nan, 12: 1500.0, 2646888559: 6})
# crosscat.observe(738, {10: 700.0, 11: nan, 12: 1500.0, 2646888559: 6})
# crosscat.observe(739, {10: 700.0, 11: nan, 12: 1500.0, 2646888559: 6})
# crosscat.observe(740, {10: 700.0, 11: nan, 12: 1500.0, 2646888559: 6})
# crosscat.observe(741, {10: 960.0, 11: nan, 12: 1360.0, 2646888559: 6})
# crosscat.observe(742, {10: 250.0, 11: 170.0, 12: 340.0, 2646888559: 6})
# crosscat.observe(743, {10: 300.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(744, {10: 300.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(745, {10: 300.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(746, {10: 3.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(752, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(753, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(754, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(755, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(756, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(757, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(758, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(759, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(760, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(761, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(762, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(763, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(764, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(765, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(766, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(767, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(768, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(769, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(770, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(771, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(772, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(773, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(774, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(775, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(776, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(777, {10: 45.0, 11: 22.0, 12: 160.0, 2646888559: 6})
# crosscat.observe(778, {10: 4.5, 11: nan, 12: 50.0, 2646888559: 6})
# crosscat.observe(779, {10: 4.5, 11: nan, 12: 50.0, 2646888559: 6})
# crosscat.observe(780, {10: 434.0, 11: nan, 12: 50.0, 2646888559: 6})
# crosscat.observe(781, {10: 4.5, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(782, {10: 60.6, 11: 50.0, 12: 54.0, 2646888559: 6})
# crosscat.observe(786, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(787, {10: 120.0, 11: nan, 12: 180.0, 2646888559: 6})
# crosscat.observe(788, {10: 825.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(790, {10: 795.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(791, {10: 795.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(792, {10: 825.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(793, {10: 825.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(794, {10: 825.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(795, {10: 810.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(797, {10: 820.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(798, {10: 10.0, 11: 10.0, 12: 6.0, 2646888559: 6})
# crosscat.observe(800, {10: 1.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(801, {10: 150.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(802, {10: 1.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(805, {10: 5.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(806, {10: 100.0, 11: nan, 12: 100.0, 2646888559: 6})
# crosscat.observe(807, {10: 130.0, 11: nan, 12: 86.0, 2646888559: 6})
# crosscat.observe(808, {10: 140.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(811, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(814, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(816, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(817, {10: 1.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(822, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(826, {10: 350.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(827, {10: 175.0, 11: 150.0, 12: nan, 2646888559: 6})
# crosscat.observe(828, {10: 175.0, 11: 150.0, 12: nan, 2646888559: 6})
# crosscat.observe(829, {10: 175.0, 11: 150.0, 12: nan, 2646888559: 6})
# crosscat.observe(830, {10: 175.0, 11: 150.0, 12: nan, 2646888559: 6})
# crosscat.observe(831, {10: 175.0, 11: 150.0, 12: nan, 2646888559: 6})
# crosscat.observe(832, {10: 113.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(834, {10: 180.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(835, {10: 70.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(840, {10: 93.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(841, {10: 225.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(842, {10: 280.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(843, {10: 280.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(844, {10: 280.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(845, {10: 280.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(846, {10: 280.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(847, {10: 280.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(848, {10: 225.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(849, {10: 225.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(850, {10: 280.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(851, {10: 250.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(852, {10: 250.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(853, {10: 250.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(854, {10: 280.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(855, {10: 280.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(856, {10: 280.0, 11: nan, 12: 300.0, 2646888559: 6})
# crosscat.observe(858, {10: 485.0, 11: 472.0, 12: 360.0, 2646888559: 6})
# crosscat.observe(860, {10: 1200.0, 11: 478.0, 12: 220.0, 2646888559: 6})
# crosscat.observe(861, {10: 1200.0, 11: 478.0, 12: 220.0, 2646888559: 6})
# crosscat.observe(862, {10: 148.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(863, {10: 407.0, 11: nan, 12: 906.0, 2646888559: 6})
# crosscat.observe(864, {10: 770.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(865, {10: 770.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(867, {10: 770.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(868, {10: 770.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(873, {10: 12.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(874, {10: 12.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(875, {10: 12.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(876, {10: 12.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(877, {10: 12.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(878, {10: 12.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(879, {10: 12.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(880, {10: 10.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(881, {10: 35.0, 11: 35.0, 12: nan, 2646888559: 6})
# crosscat.observe(882, {10: 200.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(885, {10: 1031.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(898, {10: 110.0, 11: nan, 12: 70.0, 2646888559: 6})
# crosscat.observe(899, {10: 110.0, 11: nan, 12: 70.0, 2646888559: 6})
# crosscat.observe(900, {10: 150.0, 11: nan, 12: 80.0, 2646888559: 6})
# crosscat.observe(902, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(904, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(905, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(907, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(908, {10: 50.0, 11: 48.0, 12: 120.0, 2646888559: 6})
# crosscat.observe(909, {10: 3.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(918, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(920, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(921, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(922, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(925, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(926, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(927, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(930, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(933, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(935, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(936, {10: 204.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(937, {10: 300.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(939, {10: 204.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(941, {10: 169.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(944, {10: 170.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(962, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(963, {10: 4.5, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(964, {10: 3.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(965, {10: 5.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(966, {10: 5.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(967, {10: 658.0, 11: 630.0, 12: 1065.0, 2646888559: 6})
# crosscat.observe(968, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(969, {10: 50.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(970, {10: 315.0, 11: 290.0, 12: 348.0, 2646888559: 6})
# crosscat.observe(976, {10: 117.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(977, {10: 117.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(979, {10: 720.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(980, {10: 10.9, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(981, {10: 117.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(986, {10: 3.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(987, {10: 180.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(988, {10: 137.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(989, {10: 4.3, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(990, {10: 225.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(991, {10: 225.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(992, {10: 225.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(993, {10: 225.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(994, {10: 225.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(995, {10: 225.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(996, {10: 225.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(997, {10: 225.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(998, {10: 225.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(999, {10: 93.0, 11: nan, 12: 160.0, 2646888559: 6})
# crosscat.observe(1000, {10: 150.0, 11: nan, 12: 275.0, 2646888559: 6})
# crosscat.observe(1004, {10: 0.85, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1009, {10: 468.0, 11: 369.0, 12: 608.0, 2646888559: 6})
# crosscat.observe(1010, {10: 468.0, 11: 369.0, 12: 608.0, 2646888559: 6})
# crosscat.observe(1011, {10: 468.0, 11: 369.0, 12: 608.0, 2646888559: 6})
# crosscat.observe(1013, {10: 1.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1016, {10: 450.0, 11: nan, 12: 1000.0, 2646888559: 6})
# crosscat.observe(1017, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1019, {10: 1200.0, 11: 478.0, 12: 220.0, 2646888559: 6})
# crosscat.observe(1029, {10: 300.0, 11: 260.0, 12: nan, 2646888559: 6})
# crosscat.observe(1036, {10: 1230.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1039, {10: 120.0, 11: nan, 12: 20.0, 2646888559: 6})
# crosscat.observe(1043, {10: 126.0, 11: 77.0, 12: 40.0, 2646888559: 6})
# crosscat.observe(1044, {10: 126.0, 11: 77.0, 12: 40.0, 2646888559: 6})
# crosscat.observe(1045, {10: 126.0, 11: 77.0, 12: 40.0, 2646888559: 6})
# crosscat.observe(1046, {10: 750.0, 11: 670.0, 12: 840.0, 2646888559: 6})
# crosscat.observe(1052, {10: 35.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1059, {10: 9.3, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1060, {10: 587.0, 11: nan, 12: 406.0, 2646888559: 6})
# crosscat.observe(1061, {10: 1.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1063, {10: 120.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1064, {10: 2.5, 11: nan, 12: 2.0, 2646888559: 6})
# crosscat.observe(1068, {10: 14.0, 11: 7.0, 12: 5.4, 2646888559: 6})
# crosscat.observe(1077, {10: 96.5, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1078, {10: 12.0, 11: 12.0, 12: nan, 2646888559: 6})
# crosscat.observe(1079, {10: 12.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1084, {10: 1.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1085, {10: 647.6, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1086, {10: 666.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1087, {10: 1.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1089, {10: 1.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1090, {10: 28.7, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1091, {10: 29.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1095, {10: 115.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1096, {10: 880.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1105, {10: 10.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1108, {10: 2.5, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1110, {10: 1.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1111, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1117, {10: 91.0, 11: nan, 12: 175.0, 2646888559: 6})
# crosscat.observe(1119, {10: 60.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1127, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1128, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1131, {10: 1040.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1133, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1135, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1136, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1146, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1147, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1150, {10: 92.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1151, {10: 45.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1152, {10: 1.0, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1154, {10: nan, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1155, {10: 3.5, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(1156, {10: 3.5, 11: nan, 12: nan, 2646888559: 6})
# crosscat.observe(624, {10: 14500.0, 11: nan, 12: nan, 2646888559: 7})
# crosscat.observe(625, {10: 14500.0, 11: nan, 12: nan, 2646888559: 7})
# crosscat.observe(626, {10: 14500.0, 11: nan, 12: nan, 2646888559: 7})
# crosscat.observe(727, {10: nan, 11: 5624.0, 12: nan, 2646888559: 7})
# crosscat.observe(288, {10: nan, 11: nan, 12: nan, 2646888559: 8})
# crosscat.observe(644, {10: 8000.0, 11: 4000.0, 12: nan, 2646888559: 8})
# crosscat.observe(645, {10: 8000.0, 11: 4000.0, 12: nan, 2646888559: 8})
# crosscat.observe(672, {10: 6804.0, 11: nan, 12: nan, 2646888559: 8})
# crosscat.observe(799, {10: 7000.0, 11: nan, 12: nan, 2646888559: 8})
# crosscat.observe(1053, {10: 8506.0, 11: nan, 12: nan, 2646888559: 8})
# crosscat.observe(1066, {10: 8000.0, 11: nan, 12: nan, 2646888559: 8})
# crosscat.observe(452, {10: 11110.0, 11: nan, 12: 2400.0, 2646888559: 9})

# %% [markdown]
# #### Render the posterior model trace in VentureScript.

# %%
print sample_crosscat.render_trace_in_venturescript(synthesizer.crosscat, schema, observes=True).getvalue()
# Out:
# assume variable_to_distributions = dict(
#     // Mixture models in view 0.
#     ["Eccentricity",	[
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000),
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000),
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000),
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000),
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000),
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000),
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000),
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000),
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000),
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000),
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000),
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000),
#         make_nig_normal(0.4119, 0.0009, 0.1953, 1166.0000)
#         ]],
#     // Mixture models in view 1.
#     ["Operator_Owner",	[
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959),
#         make_symm_dirichlet_categorical(0.2959)
#         ]],
#     ["Class_of_Orbit",	[
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159),
#         make_symm_dirichlet_categorical(0.0159)
#         ]],
#     ["Apogee_km",	[
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000),
#         make_nig_normal(97557.9655, 0.0009, 9456749226.0409, 1166.0000)
#         ]],
#     ["Inclination_radians",	[
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580),
#         make_nig_normal(1.0367, 0.0023, 12.0679, 270.1580)
#         ]],
#     ["Users",	[
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117)
#         ]],
#     ["Purpose",	[
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117)
#         ]],
#     ["Perigee_km",	[
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000),
#         make_nig_normal(11855.2759, 0.0098, 3225808161.1001, 1166.0000)
#         ]],
#     ["Period_minutes",	[
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000),
#         make_nig_normal(2038.6921, 0.0009, 8858425.3593, 1165.0000)
#         ]],
#     ["Anticipated_Lifetime",	[
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688),
#         make_nig_normal(8.4483, 0.7916, 220.1809, 20.8688)
#         ]],
#     ["Launch_Vehicle",	[
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819),
#         make_symm_dirichlet_categorical(0.1819)
#         ]],
#     ["Source_Used_for_Orbital_Data",	[
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693),
#         make_symm_dirichlet_categorical(0.0693)
#         ]],
#     ["Launch_Site",	[
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117),
#         make_symm_dirichlet_categorical(0.1117)
#         ]],
#     // Mixture models in view 2.
#     ["Country_of_Operator",	[
#         make_symm_dirichlet_categorical(0.1818),
#         make_symm_dirichlet_categorical(0.1818),
#         make_symm_dirichlet_categorical(0.1818),
#         make_symm_dirichlet_categorical(0.1818)
#         ]],
#     ["Type_of_Orbit",	[
#         make_symm_dirichlet_categorical(0.0932),
#         make_symm_dirichlet_categorical(0.0932),
#         make_symm_dirichlet_categorical(0.0932),
#         make_symm_dirichlet_categorical(0.0932)
#         ]],
#     ["Country_of_Contractor",	[
#         make_symm_dirichlet_categorical(0.1818),
#         make_symm_dirichlet_categorical(0.1818),
#         make_symm_dirichlet_categorical(0.1818),
#         make_symm_dirichlet_categorical(0.1818)
#         ]],
#     ["longitude_radians_of_geo",	[
#         make_nig_normal(1.6758, 0.2313, 52.0840, 28.4122),
#         make_nig_normal(1.6758, 0.2313, 52.0840, 28.4122),
#         make_nig_normal(1.6758, 0.2313, 52.0840, 28.4122),
#         make_nig_normal(1.6758, 0.2313, 52.0840, 28.4122)
#         ]],
#     ["Date_of_Launch",	[
#         make_nig_normal(37716.9310, 0.7839, 56622528.6643, 18.5771),
#         make_nig_normal(37716.9310, 0.7839, 56622528.6643, 18.5771),
#         make_nig_normal(37716.9310, 0.7839, 56622528.6643, 18.5771),
#         make_nig_normal(37716.9310, 0.7839, 56622528.6643, 18.5771)
#         ]],
#     ["Contractor",	[
#         make_symm_dirichlet_categorical(0.2962),
#         make_symm_dirichlet_categorical(0.2962),
#         make_symm_dirichlet_categorical(0.2962),
#         make_symm_dirichlet_categorical(0.2962)
#         ]],
#     // Mixture models in view 3.
#     ["Dry_Mass_kg",	[
#         make_nig_normal(3795.6207, 0.0265, 9711432.8657, 88.7305),
#         make_nig_normal(3795.6207, 0.0265, 9711432.8657, 88.7305),
#         make_nig_normal(3795.6207, 0.0265, 9711432.8657, 88.7305),
#         make_nig_normal(3795.6207, 0.0265, 9711432.8657, 88.7305),
#         make_nig_normal(3795.6207, 0.0265, 9711432.8657, 88.7305),
#         make_nig_normal(3795.6207, 0.0265, 9711432.8657, 88.7305),
#         make_nig_normal(3795.6207, 0.0265, 9711432.8657, 88.7305),
#         make_nig_normal(3795.6207, 0.0265, 9711432.8657, 88.7305),
#         make_nig_normal(3795.6207, 0.0265, 9711432.8657, 88.7305),
#         make_nig_normal(3795.6207, 0.0265, 9711432.8657, 88.7305)
#         ]],
#     ["Power_watts",	[
#         make_nig_normal(2071.2759, 0.2122, 129552890.0562, 67.1729),
#         make_nig_normal(2071.2759, 0.2122, 129552890.0562, 67.1729),
#         make_nig_normal(2071.2759, 0.2122, 129552890.0562, 67.1729),
#         make_nig_normal(2071.2759, 0.2122, 129552890.0562, 67.1729),
#         make_nig_normal(2071.2759, 0.2122, 129552890.0562, 67.1729),
#         make_nig_normal(2071.2759, 0.2122, 129552890.0562, 67.1729),
#         make_nig_normal(2071.2759, 0.2122, 129552890.0562, 67.1729),
#         make_nig_normal(2071.2759, 0.2122, 129552890.0562, 67.1729),
#         make_nig_normal(2071.2759, 0.2122, 129552890.0562, 67.1729),
#         make_nig_normal(2071.2759, 0.2122, 129552890.0562, 67.1729)
#         ]],
#     ["Launch_Mass_kg",	[
#         make_nig_normal(5588.3103, 0.0064, 57332857.4868, 199.9460),
#         make_nig_normal(5588.3103, 0.0064, 57332857.4868, 199.9460),
#         make_nig_normal(5588.3103, 0.0064, 57332857.4868, 199.9460),
#         make_nig_normal(5588.3103, 0.0064, 57332857.4868, 199.9460),
#         make_nig_normal(5588.3103, 0.0064, 57332857.4868, 199.9460),
#         make_nig_normal(5588.3103, 0.0064, 57332857.4868, 199.9460),
#         make_nig_normal(5588.3103, 0.0064, 57332857.4868, 199.9460),
#         make_nig_normal(5588.3103, 0.0064, 57332857.4868, 199.9460),
#         make_nig_normal(5588.3103, 0.0064, 57332857.4868, 199.9460),
#         make_nig_normal(5588.3103, 0.0064, 57332857.4868, 199.9460)
#         ]]
# );
#
# assume variable_to_view_assignment = dict(
#     ["Eccentricity", 0],
#     ["Operator_Owner", 1],
#     ["Users", 1],
#     ["Purpose", 1],
#     ["Class_of_Orbit", 1],
#     ["Perigee_km", 1],
#     ["Apogee_km", 1],
#     ["Period_minutes", 1],
#     ["Anticipated_Lifetime", 1],
#     ["Launch_Site", 1],
#     ["Launch_Vehicle", 1],
#     ["Source_Used_for_Orbital_Data", 1],
#     ["Inclination_radians", 1],
#     ["Country_of_Operator", 2],
#     ["Type_of_Orbit", 2],
#     ["Date_of_Launch", 2],
#     ["Contractor", 2],
#     ["Country_of_Contractor", 2],
#     ["longitude_radians_of_geo", 2],
#     ["Launch_Mass_kg", 3],
#     ["Dry_Mass_kg", 3],
#     ["Power_watts", 3]
# );
#
# assume view_to_mixture_weights = dict(
#     [0,	 simplex(0.9443,0.0129,0.0103,0.0120,0.0017,0.0043,0.0017,0.0009,0.0060,0.0017,0.0026,0.0009,0.0009)],
#     [1,	 simplex(0.0617,0.3728,0.0034,0.5219,0.0017,0.0026,0.0034,0.0017,0.0129,0.0051,0.0034,0.0026,0.0017,0.0009,0.0009,0.0009,0.0009,0.0009,0.0009)],
#     [2,	 simplex(0.6718,0.3042,0.0231,0.0009)],
#     [3,	 simplex(0.1345,0.0111,0.2057,0.1748,0.0043,0.0283,0.4310,0.0034,0.0060,0.0009)]
# );
#
# assume get_row_mixture_assignment = mem((rowid, view) ~> {
#     weights = view_to_mixture_weights[view];
#     categorical(weights) #mixture_assignment:pair(rowid, view)
# });
#
# assume get_cell_value = (rowid, variable) ~> {
#     view = variable_to_view_assignment[variable];
#     row_mixture_assignment = get_row_mixture_assignment(rowid, view);
#     sampler = variable_to_distributions[variable][row_mixture_assignment];
#     sampler() #cell_value:pair(rowid, variable)
# };
#
# // Observe mixture assignment of each rowid in each view.
# observe get_row_mixture_assignment(rowid: 0, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 1, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 2, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 3, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 4, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 5, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 6, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 7, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 8, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 9, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 10, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 11, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 12, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 13, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 14, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 15, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 17, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 18, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 19, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 20, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 21, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 22, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 23, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 24, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 25, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 26, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 27, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 29, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 30, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 31, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 32, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 33, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 34, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 35, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 36, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 37, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 38, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 39, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 40, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 41, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 42, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 43, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 44, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 45, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 46, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 47, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 48, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 49, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 50, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 51, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 52, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 53, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 54, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 55, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 56, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 57, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 58, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 59, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 60, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 61, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 62, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 63, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 64, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 65, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 66, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 67, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 68, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 69, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 70, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 71, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 72, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 73, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 74, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 75, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 76, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 77, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 78, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 79, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 80, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 81, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 82, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 83, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 84, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 85, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 86, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 87, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 88, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 89, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 90, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 91, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 92, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 93, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 94, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 95, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 96, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 97, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 98, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 99, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 100, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 101, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 102, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 103, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 105, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 106, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 107, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 108, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 109, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 110, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 111, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 112, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 113, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 114, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 115, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 116, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 117, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 118, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 119, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 120, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 121, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 122, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 123, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 124, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 125, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 126, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 127, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 128, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 130, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 132, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 133, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 134, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 135, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 136, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 137, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 138, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 139, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 140, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 141, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 142, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 143, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 144, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 145, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 146, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 147, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 148, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 149, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 150, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 151, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 152, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 153, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 154, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 155, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 156, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 157, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 158, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 159, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 160, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 161, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 162, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 163, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 164, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 165, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 166, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 167, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 168, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 170, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 171, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 172, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 173, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 174, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 175, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 177, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 178, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 180, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 181, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 182, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 183, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 184, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 185, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 186, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 187, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 188, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 189, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 190, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 191, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 192, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 193, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 194, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 195, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 196, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 197, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 198, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 199, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 200, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 201, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 202, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 203, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 204, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 205, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 206, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 207, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 208, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 209, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 210, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 211, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 212, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 213, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 214, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 215, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 216, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 217, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 218, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 220, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 221, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 222, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 223, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 224, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 225, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 226, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 227, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 229, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 230, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 231, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 232, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 233, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 235, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 236, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 237, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 238, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 239, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 240, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 241, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 242, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 243, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 245, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 246, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 247, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 248, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 249, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 250, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 251, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 252, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 253, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 254, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 255, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 256, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 257, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 258, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 259, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 260, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 261, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 262, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 263, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 264, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 265, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 266, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 267, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 268, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 269, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 270, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 271, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 272, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 273, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 274, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 275, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 276, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 277, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 278, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 279, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 280, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 281, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 282, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 283, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 284, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 285, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 286, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 287, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 288, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 289, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 290, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 291, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 292, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 293, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 294, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 295, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 296, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 297, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 298, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 299, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 300, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 301, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 302, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 303, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 304, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 305, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 306, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 307, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 308, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 309, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 310, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 311, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 312, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 313, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 314, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 315, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 316, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 317, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 318, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 319, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 320, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 321, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 322, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 323, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 324, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 325, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 326, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 327, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 328, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 329, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 330, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 332, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 333, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 334, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 335, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 336, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 337, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 338, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 339, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 340, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 341, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 343, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 344, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 345, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 346, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 347, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 348, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 349, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 350, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 351, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 352, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 353, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 354, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 355, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 356, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 357, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 358, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 359, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 360, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 361, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 362, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 363, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 364, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 365, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 366, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 367, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 368, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 369, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 370, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 371, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 372, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 373, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 374, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 375, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 376, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 377, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 378, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 379, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 380, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 381, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 382, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 383, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 384, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 385, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 386, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 387, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 388, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 390, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 391, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 392, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 393, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 394, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 395, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 396, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 397, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 398, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 399, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 400, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 401, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 402, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 404, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 405, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 406, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 407, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 408, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 409, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 410, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 411, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 412, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 413, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 414, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 415, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 416, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 417, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 418, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 419, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 420, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 421, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 422, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 423, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 424, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 425, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 426, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 427, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 428, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 429, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 430, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 431, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 432, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 433, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 434, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 435, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 436, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 437, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 438, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 439, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 440, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 441, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 442, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 443, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 444, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 445, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 446, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 447, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 448, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 449, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 450, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 451, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 452, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 453, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 454, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 455, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 456, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 457, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 458, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 459, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 460, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 461, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 462, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 463, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 464, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 467, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 468, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 469, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 470, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 471, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 472, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 473, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 474, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 475, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 476, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 477, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 478, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 479, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 480, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 481, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 482, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 484, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 485, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 486, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 487, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 488, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 489, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 490, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 491, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 492, view:0) = 0;
# observe get_row_mixture_assignment(rowid: 493, view:0) = 0;
# ...
# observe get_cell_value(rowid:452, "Power_watts") = 160.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 45.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 22.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 160.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 45.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 22.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 160.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 45.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 22.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 160.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 45.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 22.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 160.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 45.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 22.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 160.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 45.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 22.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 160.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 4.5000;
# observe get_cell_value(rowid:452, "Power_watts") = 50.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 4.5000;
# observe get_cell_value(rowid:452, "Power_watts") = 50.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 434.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 50.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 4.5000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 60.6000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 50.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 54.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 120.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 180.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 825.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 795.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 795.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 825.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 825.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 825.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 810.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 820.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 10.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 10.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 6.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 150.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 5.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 100.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 100.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 130.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 86.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 140.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 350.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 175.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 150.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 175.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 150.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 175.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 150.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 175.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 150.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 175.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 150.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 113.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 180.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 70.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 93.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 225.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 280.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 280.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 280.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 280.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 280.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 280.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 225.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 225.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 280.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 250.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 250.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 250.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 280.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 280.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 280.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 485.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 472.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 360.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1200.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 478.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 220.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1200.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 478.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 220.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 148.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 407.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 906.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 770.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 770.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 770.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 770.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 12.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 12.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 12.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 12.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 12.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 12.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 12.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 10.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 35.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 35.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 200.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1031.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 110.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 70.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 110.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 70.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 150.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 80.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 50.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 48.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 120.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 3.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 204.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 300.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 204.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 169.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 170.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 4.5000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 3.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 5.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 5.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 658.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 630.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 1065.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 50.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 315.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 290.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 348.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 117.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 117.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 720.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 10.9000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 117.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 3.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 180.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 137.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 4.3000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 225.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 225.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 225.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 225.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 225.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 225.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 225.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 225.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 225.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 93.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 160.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 150.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 275.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 0.8500;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 468.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 369.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 608.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 468.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 369.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 608.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 468.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 369.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 608.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 450.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 1000.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1200.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 478.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 220.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 300.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 260.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1230.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 120.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 20.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 126.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 77.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 40.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 126.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 77.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 40.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 126.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 77.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 40.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 750.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 670.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 840.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 35.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 9.3000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 587.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 406.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 120.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 2.5000;
# observe get_cell_value(rowid:452, "Power_watts") = 2.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 14.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 7.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 5.4000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 96.5000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 12.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 12.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 12.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 647.6000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 666.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 28.7000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 29.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 115.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 880.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 10.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 2.5000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 91.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 175.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 60.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1040.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 92.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 45.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 1.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 3.5000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 3.5000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 14500.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 14500.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 14500.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 5624.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 8000.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 4000.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 8000.0000;
# observe get_cell_value(rowid:452, "Dry_Mass_kg") = 4000.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 6804.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 7000.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 8506.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 8000.0000;
# observe get_cell_value(rowid:452, "Launch_Mass_kg") = 11110.0000;
# observe get_cell_value(rowid:452, "Power_watts") = 2400.0000;
